# %%
import numpy as np

# %%
def evaluation_forward(A, B, PI, O, alpha):
    alpha[:, 0] = np.multiply(PI, B[:, O[0]])
    for t in range(1, O.shape[0]):
        for j in range(A.shape[0]):
            alpha[j, t] = np.sum(np.multiply(alpha[:, t - 1], A[:, j])) * B[j, O[t]]
    return alpha

# %%
def evaluation_backward(A, B, PI, O, beta):
    beta[:, -1] = np.ones((A.shape[0]), dtype=np.float64)
    for t in range(O.shape[0] - 2, -1, -1):
        for i in range(A.shape[0]):
            beta[i, t] = np.sum(np.multiply(np.multiply(A[i, :], B[:, O[t]]), beta[:, t + 1]))
    return beta

# %%
def decode(A, B, PI, O, delta):
    delta[:, 0] = np.multiply(PI, B[:, O[0]])
    for t in range(1, O.shape[0]):
        for j in range(A.shape[0]):
            delta[j, t] = np.amax(np.multiply(delta[:, t - 1], A[:, j])) * B[j, O[t]]
    path = np.argmax(delta, axis=0) + 1
    return delta, path

# %%
def learn(A, B, PI, O, V, alpha, beta, XI, gamma, epsilon=10e-12):
    alpha = evaluation_forward(A, B, PI, O, alpha)
    beta = evaluation_backward(A, B, PI, O, beta)
    
    #Compute XI#
    p = np.sum(np.multiply(alpha, beta), axis=0)
    for t in range(O.shape[0] - 1):
        for i in range(A.shape[0]):
            for j in range(A.shape[0]):
                XI[i, j, t] = (alpha[i, t] * beta[j, t + 1] * A[i, j] * B[j, O[t + 1]]) / (p[t] + epsilon)
    
    #Compute gamma#
    for t in range(O.shape[0]):
        for i in range(A.shape[0]):
            gamma[i, t] = np.sum(XI[i, :, t])
            
    #Compute new A#
    for i in range(A.shape[0]):
        for j in range(B.shape[0]):
            A[i, j] = np.sum(XI[i, j, :]) / (np.sum(gamma[i]) + epsilon)

    #Compute new PI#
    for i in range(A.shape[0]):
        PI[i] = gamma[i, 0]
        
    #Compute new B#
    for j in range(A.shape[0]):
        for k in range(V.shape[0]):
            B[j, k] = np.sum(np.multiply(gamma[j], (O == V[k]).astype(np.float64))) / (np.sum(gamma[j]) + epsilon)
    return A, B, PI, gamma, XI, alpha, beta

# %%
A = np.array([ #1st Rank = From State, 2nd Rank = To State
    [1 / 3, 1 / 3, 1 / 3],
    [1 / 3, 1 / 3, 1 / 3],
    [1 / 3, 1 / 3, 1 / 3]
], dtype=np.float64)
PI = np.array([1/ 3, 1 / 3, 1 / 3], dtype=np.float64) #1st Rank = Init State
B = np.array([ #1st Rankg = State, 2nd Rank = Output Value
    [4 / 6, 2 / 6],
    [2 / 6, 4 / 6],
    [3 / 6, 3 / 6]
], dtype=np.float64)
O = np.array([0, 0, 1, 0, 1], dtype=np.int32) #0 = red, 1 = blue
V = np.array([0, 1], dtype=np.int32) #0 = red, 1 = blue
alpha = np.zeros((B.shape[0], O.shape[0]), dtype=np.float64) #1st Rank = State, 2nd Rank = Time
beta = np.zeros((B.shape[0], O.shape[0]), dtype=np.float64) #1st Rank = State, 2nd Rank = Time
delta = np.zeros((B.shape[0], O.shape[0]), dtype=np.float64) #1st Rank = State, 2nd Rank = Time
gamma = np.zeros((B.shape[0], O.shape[0]), dtype=np.float64) #1st Rank = State, 2nd Rank = Time
XI = np.zeros((B.shape[0], B.shape[0], O.shape[0]), dtype=np.float64) #1st Rank = From State, 2nd Rank = To State, 3rd Rank = Time

# %%
records = list()
records.append((np.copy(A), np.copy(B), np.copy(PI)))
for i in range(10000):
    A, B, PI, gamma, XI, alpha, beta = learn(A, B, PI, O, V, alpha, beta, XI, gamma)
    delta, path = decode(A, B, PI, O, delta)
    records.append((np.copy(A), np.copy(B), np.copy(PI)))
    print('Iters {}, Path: {}'.format(i + 1, path))
# Out:
# Iters 1, Path: [1 1 2 1 2]
# Iters 2, Path: [1 1 2 1 2]
# Iters 3, Path: [1 1 2 1 2]
# Iters 4, Path: [1 1 2 1 2]
# Iters 5, Path: [1 3 2 1 2]
# Iters 6, Path: [1 1 2 1 2]
# Iters 7, Path: [1 3 2 1 2]
# Iters 8, Path: [1 1 2 1 2]
# Iters 9, Path: [1 3 3 1 2]
# Iters 10, Path: [1 1 3 1 3]
# Iters 11, Path: [1 3 3 3 3]
# Iters 12, Path: [1 3 3 1 3]
# Iters 13, Path: [1 3 3 3 3]
# Iters 14, Path: [1 3 3 1 3]
# Iters 15, Path: [1 3 3 3 3]
# Iters 16, Path: [1 1 3 1 3]
# Iters 17, Path: [1 3 3 3 3]
# Iters 18, Path: [1 1 3 1 3]
# Iters 19, Path: [1 3 3 3 3]
# Iters 20, Path: [1 1 3 1 3]
# Iters 21, Path: [1 3 3 3 3]
# Iters 22, Path: [1 1 3 1 3]
# Iters 23, Path: [1 3 3 3 3]
# Iters 24, Path: [1 1 3 1 3]
# Iters 25, Path: [1 3 3 3 3]
# Iters 26, Path: [1 1 3 1 3]
# Iters 27, Path: [1 3 3 3 3]
# Iters 28, Path: [1 1 3 1 3]
# Iters 29, Path: [1 3 3 3 3]
# Iters 30, Path: [1 1 3 1 3]
# Iters 31, Path: [1 3 3 3 3]
# Iters 32, Path: [1 1 3 1 3]
# Iters 33, Path: [1 3 3 3 3]
# Iters 34, Path: [1 1 3 1 3]
# Iters 35, Path: [1 3 3 3 3]
# Iters 36, Path: [1 1 3 1 3]
# Iters 37, Path: [1 3 3 3 3]
# Iters 38, Path: [1 1 3 1 3]
# Iters 39, Path: [1 3 3 3 3]
# Iters 40, Path: [1 1 3 1 3]
# Iters 41, Path: [1 3 3 3 3]
# Iters 42, Path: [1 1 3 1 3]
# Iters 43, Path: [1 3 3 3 3]
# Iters 44, Path: [1 1 3 1 3]
# Iters 45, Path: [1 3 3 3 3]
# Iters 46, Path: [1 1 3 1 3]
# Iters 47, Path: [1 3 3 3 3]
# Iters 48, Path: [1 1 3 1 3]
# Iters 49, Path: [1 3 3 3 3]
# Iters 50, Path: [1 1 3 1 3]
# Iters 51, Path: [1 3 3 3 3]
# Iters 52, Path: [1 1 3 1 3]
# Iters 53, Path: [1 3 3 3 3]
# Iters 54, Path: [1 3 3 1 3]
# Iters 55, Path: [1 3 3 3 3]
# Iters 56, Path: [1 1 3 1 3]
# Iters 57, Path: [1 3 3 3 3]
# Iters 58, Path: [1 3 3 1 3]
# Iters 59, Path: [1 3 3 3 3]
# Iters 60, Path: [1 1 3 1 3]
# Iters 61, Path: [1 3 3 3 3]
# Iters 62, Path: [1 3 3 3 3]
# Iters 63, Path: [1 3 3 3 3]
# Iters 64, Path: [1 1 3 1 3]
# Iters 65, Path: [1 3 3 3 3]
# Iters 66, Path: [1 3 3 3 3]
# Iters 67, Path: [1 3 3 3 3]
# Iters 68, Path: [1 1 3 1 3]
# Iters 69, Path: [1 3 3 3 3]
# Iters 70, Path: [1 3 3 3 3]
# Iters 71, Path: [1 3 3 3 3]
# Iters 72, Path: [1 1 3 1 3]
# Iters 73, Path: [1 3 3 3 3]
# Iters 74, Path: [1 3 3 3 3]
# Iters 75, Path: [1 3 3 3 3]
# Iters 76, Path: [1 1 3 1 3]
# Iters 77, Path: [1 3 3 3 3]
# Iters 78, Path: [1 3 3 3 3]
# Iters 79, Path: [1 3 3 3 3]
# Iters 80, Path: [1 1 3 1 3]
# Iters 81, Path: [1 3 3 3 3]
# Iters 82, Path: [1 3 3 3 3]
# Iters 83, Path: [1 3 3 3 3]
# Iters 84, Path: [1 1 3 1 3]
# Iters 85, Path: [1 3 3 3 3]
# Iters 86, Path: [1 3 3 3 3]
# Iters 87, Path: [1 3 3 3 3]
# Iters 88, Path: [1 1 3 1 3]
# Iters 89, Path: [1 3 3 3 3]
# Iters 90, Path: [1 3 3 3 3]
# Iters 91, Path: [1 3 3 3 3]
# Iters 92, Path: [1 1 3 1 3]
# Iters 93, Path: [1 3 3 3 3]
# Iters 94, Path: [1 3 3 3 3]
# Iters 95, Path: [1 3 3 3 3]
# Iters 96, Path: [1 1 3 1 3]
# Iters 97, Path: [1 3 3 3 3]
# Iters 98, Path: [1 3 3 3 3]
# Iters 99, Path: [1 3 3 3 3]
# Iters 100, Path: [1 1 3 1 3]
# Iters 101, Path: [1 3 3 3 3]
# Iters 102, Path: [1 3 3 3 3]
# Iters 103, Path: [1 3 3 3 3]
# Iters 104, Path: [1 1 3 1 3]
# Iters 105, Path: [1 3 3 3 3]
# Iters 106, Path: [1 3 3 3 3]
# Iters 107, Path: [1 3 3 3 3]
# Iters 108, Path: [1 1 3 1 3]
# Iters 109, Path: [1 3 3 3 3]
# Iters 110, Path: [1 3 3 3 3]
# Iters 111, Path: [1 3 3 3 3]
# Iters 112, Path: [1 1 3 1 3]
# Iters 113, Path: [1 3 3 3 3]
# Iters 114, Path: [1 3 3 3 3]
# Iters 115, Path: [1 3 3 3 3]
# Iters 116, Path: [1 1 3 1 3]
# Iters 117, Path: [1 3 3 3 3]
# Iters 118, Path: [1 3 3 3 3]
# Iters 119, Path: [1 3 3 3 3]
# Iters 120, Path: [1 1 3 1 3]
# Iters 121, Path: [1 3 3 3 3]
# Iters 122, Path: [1 3 3 3 3]
# Iters 123, Path: [1 3 3 3 3]
# Iters 124, Path: [1 1 3 1 3]
# Iters 125, Path: [1 3 3 3 3]
# Iters 126, Path: [1 3 3 3 3]
# Iters 127, Path: [1 3 3 3 3]
# Iters 128, Path: [1 1 3 1 3]
# Iters 129, Path: [1 3 3 3 3]
# Iters 130, Path: [1 3 3 3 3]
# Iters 131, Path: [1 3 3 3 3]
# Iters 132, Path: [1 1 3 1 3]
# Iters 133, Path: [1 3 3 3 3]
# Iters 134, Path: [1 3 3 3 3]
# Iters 135, Path: [1 3 3 3 3]
# Iters 136, Path: [1 1 3 1 3]
# Iters 137, Path: [1 3 3 3 3]
# Iters 138, Path: [1 3 3 3 3]
# Iters 139, Path: [1 3 3 3 3]
# Iters 140, Path: [1 1 3 1 3]
# Iters 141, Path: [1 3 3 3 3]
# Iters 142, Path: [1 3 3 3 3]
# Iters 143, Path: [1 3 3 3 3]
# Iters 144, Path: [1 1 3 1 3]
# Iters 145, Path: [1 3 3 3 3]
# Iters 146, Path: [1 3 3 3 3]
# Iters 147, Path: [1 3 3 3 3]
# Iters 148, Path: [1 1 3 1 3]
# Iters 149, Path: [1 3 3 3 3]
# Iters 150, Path: [1 3 3 3 3]
# Iters 151, Path: [1 3 3 3 3]
# Iters 152, Path: [1 1 3 1 3]
# Iters 153, Path: [1 3 3 3 3]
# Iters 154, Path: [1 3 3 3 3]
# Iters 155, Path: [1 3 3 3 3]
# Iters 156, Path: [1 1 3 1 3]
# Iters 157, Path: [1 3 3 3 3]
# Iters 158, Path: [1 3 3 3 3]
# Iters 159, Path: [1 3 3 3 3]
# Iters 160, Path: [1 1 3 1 3]
# Iters 161, Path: [1 3 3 3 3]
# Iters 162, Path: [1 3 3 3 3]
# Iters 163, Path: [1 3 3 3 3]
# Iters 164, Path: [1 1 3 1 3]
# Iters 165, Path: [1 3 3 3 3]
# Iters 166, Path: [1 3 3 3 3]
# Iters 167, Path: [1 3 3 3 3]
# Iters 168, Path: [1 1 3 1 3]
# Iters 169, Path: [1 3 3 3 3]
# Iters 170, Path: [1 3 3 3 3]
# Iters 171, Path: [1 3 3 3 3]
# Iters 172, Path: [1 1 3 1 3]
# Iters 173, Path: [1 3 3 3 3]
# Iters 174, Path: [1 3 3 3 3]
# Iters 175, Path: [1 3 3 3 3]
# Iters 176, Path: [1 1 3 1 3]
# Iters 177, Path: [1 3 3 3 3]
# Iters 178, Path: [1 3 3 3 3]
# Iters 179, Path: [1 3 3 3 3]
# Iters 180, Path: [1 1 3 1 3]
# Iters 181, Path: [1 3 3 3 3]
# Iters 182, Path: [1 3 3 3 3]
# Iters 183, Path: [1 3 3 3 3]
# Iters 184, Path: [1 1 3 1 3]
# Iters 185, Path: [1 3 3 3 3]
# Iters 186, Path: [1 3 3 3 3]
# Iters 187, Path: [1 3 3 3 3]
# Iters 188, Path: [1 1 3 1 3]
# Iters 189, Path: [1 3 3 3 3]
# Iters 190, Path: [1 3 3 3 3]
# Iters 191, Path: [1 3 3 3 3]
# Iters 192, Path: [1 1 3 1 3]
# Iters 193, Path: [1 3 3 3 3]
# Iters 194, Path: [1 3 3 3 3]
# Iters 195, Path: [1 3 3 3 3]
# Iters 196, Path: [1 1 3 1 3]
# Iters 197, Path: [1 3 3 3 3]
# Iters 198, Path: [1 3 3 3 3]
# Iters 199, Path: [1 3 3 3 3]
# Iters 200, Path: [1 1 3 1 3]
# Iters 201, Path: [1 3 3 3 3]
# Iters 202, Path: [1 3 3 3 3]
# Iters 203, Path: [1 3 3 3 3]
# Iters 204, Path: [1 1 3 1 3]
# Iters 205, Path: [1 3 3 3 3]
# Iters 206, Path: [1 3 3 3 3]
# Iters 207, Path: [1 3 3 3 3]
# Iters 208, Path: [1 1 3 1 3]
# Iters 209, Path: [1 3 3 3 3]
# Iters 210, Path: [1 3 3 3 3]
# Iters 211, Path: [1 3 3 3 3]
# Iters 212, Path: [1 1 3 1 3]
# Iters 213, Path: [1 3 3 3 3]
# Iters 214, Path: [1 3 3 3 3]
# Iters 215, Path: [1 3 3 3 3]
# Iters 216, Path: [1 1 3 1 3]
# Iters 217, Path: [1 3 3 3 3]
# Iters 218, Path: [1 3 3 3 3]
# Iters 219, Path: [1 3 3 3 3]
# Iters 220, Path: [1 1 3 1 3]
# Iters 221, Path: [1 3 3 3 3]
# Iters 222, Path: [1 3 3 3 3]
# Iters 223, Path: [1 3 3 3 3]
# Iters 224, Path: [1 1 3 1 3]
# Iters 225, Path: [1 3 3 3 3]
# Iters 226, Path: [1 3 3 3 3]
# Iters 227, Path: [1 3 3 3 3]
# Iters 228, Path: [1 1 3 1 3]
# Iters 229, Path: [1 3 3 3 3]
# Iters 230, Path: [1 3 3 3 3]
# Iters 231, Path: [1 3 3 3 3]
# Iters 232, Path: [1 1 3 1 3]
# Iters 233, Path: [1 3 3 3 3]
# Iters 234, Path: [1 3 3 3 3]
# Iters 235, Path: [1 3 3 3 3]
# Iters 236, Path: [1 1 3 1 3]
# Iters 237, Path: [1 3 3 3 3]
# Iters 238, Path: [1 3 3 3 3]
# Iters 239, Path: [1 3 3 3 3]
# Iters 240, Path: [1 1 3 1 3]
# Iters 241, Path: [1 3 3 3 3]
# Iters 242, Path: [1 3 3 3 3]
# Iters 243, Path: [1 3 3 3 3]
# Iters 244, Path: [1 1 3 1 3]
# Iters 245, Path: [1 3 3 3 3]
# Iters 246, Path: [1 3 3 3 3]
# Iters 247, Path: [1 3 3 3 3]
# Iters 248, Path: [1 1 3 1 3]
# Iters 249, Path: [1 3 3 3 3]
# Iters 250, Path: [1 3 3 3 3]
# Iters 251, Path: [1 3 3 3 3]
# Iters 252, Path: [1 1 3 1 3]
# Iters 253, Path: [1 3 3 3 3]
# Iters 254, Path: [1 3 3 3 3]
# Iters 255, Path: [1 3 3 3 3]
# Iters 256, Path: [1 1 3 1 3]
# Iters 257, Path: [1 3 3 3 3]
# Iters 258, Path: [1 3 3 3 3]
# Iters 259, Path: [1 3 3 3 3]
# Iters 260, Path: [1 1 3 1 3]
# Iters 261, Path: [1 3 3 3 3]
# Iters 262, Path: [1 3 3 3 3]
# Iters 263, Path: [1 3 3 3 3]
# Iters 264, Path: [1 1 3 1 3]
# Iters 265, Path: [1 3 3 3 3]
# Iters 266, Path: [1 3 3 3 3]
# Iters 267, Path: [1 3 3 3 3]
# Iters 268, Path: [1 1 3 1 3]
# Iters 269, Path: [1 3 3 3 3]
# Iters 270, Path: [1 3 3 3 3]
# Iters 271, Path: [1 3 3 3 3]
# Iters 272, Path: [1 1 3 1 3]
# Iters 273, Path: [1 3 3 3 3]
# Iters 274, Path: [1 3 3 3 3]
# Iters 275, Path: [1 3 3 3 3]
# Iters 276, Path: [1 1 3 1 3]
# Iters 277, Path: [1 3 3 3 3]
# Iters 278, Path: [1 3 3 3 3]
# Iters 279, Path: [1 3 3 3 3]
# Iters 280, Path: [1 1 3 1 3]
# Iters 281, Path: [1 3 3 3 3]
# Iters 282, Path: [1 3 3 3 3]
# Iters 283, Path: [1 3 3 3 3]
# Iters 284, Path: [1 1 3 1 3]
# Iters 285, Path: [1 3 3 3 3]
# Iters 286, Path: [1 3 3 3 3]
# Iters 287, Path: [1 3 3 3 3]
# Iters 288, Path: [1 1 3 1 3]
# Iters 289, Path: [1 3 3 3 3]
# Iters 290, Path: [1 3 3 3 3]
# Iters 291, Path: [1 3 3 3 3]
# Iters 292, Path: [1 1 3 1 3]
# Iters 293, Path: [1 3 3 3 3]
# Iters 294, Path: [1 3 3 3 3]
# Iters 295, Path: [1 3 3 3 3]
# Iters 296, Path: [1 1 3 1 3]
# Iters 297, Path: [1 3 3 3 3]
# Iters 298, Path: [1 3 3 3 3]
# Iters 299, Path: [1 3 3 3 3]
# Iters 300, Path: [1 1 3 1 3]
# Iters 301, Path: [1 3 3 3 3]
# Iters 302, Path: [1 3 3 3 3]
# Iters 303, Path: [1 3 3 3 3]
# Iters 304, Path: [1 1 3 1 3]
# Iters 305, Path: [1 3 3 3 3]
# Iters 306, Path: [1 3 3 3 3]
# Iters 307, Path: [1 3 3 3 3]
# Iters 308, Path: [1 1 3 1 3]
# Iters 309, Path: [1 3 3 3 3]
# Iters 310, Path: [1 3 3 3 3]
# Iters 311, Path: [1 3 3 3 3]
# Iters 312, Path: [1 1 3 1 3]
# Iters 313, Path: [1 3 3 3 3]
# Iters 314, Path: [1 3 3 3 3]
# Iters 315, Path: [1 3 3 3 3]
# Iters 316, Path: [1 1 3 1 3]
# Iters 317, Path: [1 3 3 3 3]
# Iters 318, Path: [1 3 3 3 3]
# Iters 319, Path: [1 3 3 3 3]
# Iters 320, Path: [1 1 3 1 3]
# Iters 321, Path: [1 3 3 3 3]
# Iters 322, Path: [1 3 3 3 3]
# Iters 323, Path: [1 3 3 3 3]
# Iters 324, Path: [1 1 3 1 3]
# Iters 325, Path: [1 3 3 3 3]
# Iters 326, Path: [1 3 3 3 3]
# Iters 327, Path: [1 3 3 3 3]
# Iters 328, Path: [1 1 3 1 3]
# Iters 329, Path: [1 3 3 3 3]
# Iters 330, Path: [1 3 3 3 3]
# Iters 331, Path: [1 3 3 3 3]
# Iters 332, Path: [1 1 3 1 3]
# Iters 333, Path: [1 3 3 3 3]
# Iters 334, Path: [1 3 3 3 3]
# Iters 335, Path: [1 3 3 3 3]
# Iters 336, Path: [1 1 3 1 3]
# Iters 337, Path: [1 3 3 3 3]
# Iters 338, Path: [1 3 3 3 3]
# Iters 339, Path: [1 3 3 3 3]
# Iters 340, Path: [1 1 3 1 3]
# Iters 341, Path: [1 3 3 3 3]
# Iters 342, Path: [1 3 3 3 3]
# Iters 343, Path: [1 3 3 3 3]
# Iters 344, Path: [1 1 3 1 3]
# Iters 345, Path: [1 3 3 3 3]
# Iters 346, Path: [1 3 3 3 3]
# Iters 347, Path: [1 3 3 3 3]
# Iters 348, Path: [1 1 3 1 3]
# Iters 349, Path: [1 3 3 3 3]
# Iters 350, Path: [1 3 3 3 3]
# Iters 351, Path: [1 3 3 3 3]
# Iters 352, Path: [1 1 3 1 3]
# Iters 353, Path: [1 3 3 3 3]
# Iters 354, Path: [1 3 3 3 3]
# Iters 355, Path: [1 3 3 3 3]
# Iters 356, Path: [1 1 3 1 3]
# Iters 357, Path: [1 3 3 3 3]
# Iters 358, Path: [1 3 3 3 3]
# Iters 359, Path: [1 3 3 3 3]
# Iters 360, Path: [1 1 3 1 3]
# Iters 361, Path: [1 3 3 3 3]
# Iters 362, Path: [1 3 3 3 3]
# Iters 363, Path: [1 3 3 3 3]
# Iters 364, Path: [1 1 3 1 3]
# Iters 365, Path: [1 3 3 3 3]
# Iters 366, Path: [1 3 3 3 3]
# Iters 367, Path: [1 3 3 3 3]
# Iters 368, Path: [1 1 3 1 3]
# Iters 369, Path: [1 3 3 3 3]
# Iters 370, Path: [1 3 3 3 3]
# Iters 371, Path: [1 3 3 3 3]
# Iters 372, Path: [1 1 3 1 3]
# Iters 373, Path: [1 3 3 3 3]
# Iters 374, Path: [1 3 3 3 3]
# Iters 375, Path: [1 3 3 3 3]
# Iters 376, Path: [1 1 3 1 3]
# Iters 377, Path: [1 3 3 3 3]
# Iters 378, Path: [1 3 3 3 3]
# Iters 379, Path: [1 3 3 3 3]
# Iters 380, Path: [1 1 3 1 3]
# Iters 381, Path: [1 3 3 3 3]
# Iters 382, Path: [1 3 3 3 3]
# Iters 383, Path: [1 3 3 3 3]
# Iters 384, Path: [1 1 3 1 3]
# Iters 385, Path: [1 3 3 3 3]
# Iters 386, Path: [1 3 3 3 3]
# Iters 387, Path: [1 3 3 3 3]
# Iters 388, Path: [1 1 3 1 3]
# Iters 389, Path: [1 3 3 3 3]
# Iters 390, Path: [1 3 3 3 3]
# Iters 391, Path: [1 3 3 3 3]
# Iters 392, Path: [1 1 3 1 3]
# Iters 393, Path: [1 3 3 3 3]
# Iters 394, Path: [1 3 3 3 3]
# Iters 395, Path: [1 3 3 3 3]
# Iters 396, Path: [1 1 3 1 3]
# Iters 397, Path: [1 3 3 3 3]
# Iters 398, Path: [1 3 3 3 3]
# Iters 399, Path: [1 3 3 3 3]
# Iters 400, Path: [1 1 3 1 3]
# Iters 401, Path: [1 3 3 3 3]
# Iters 402, Path: [1 3 3 3 3]
# Iters 403, Path: [1 3 3 3 3]
# Iters 404, Path: [1 1 3 1 3]
# Iters 405, Path: [1 3 3 3 3]
# Iters 406, Path: [1 3 3 3 3]
# Iters 407, Path: [1 3 3 3 3]
# Iters 408, Path: [1 1 3 1 3]
# Iters 409, Path: [1 3 3 3 3]
# Iters 410, Path: [1 3 3 3 3]
# Iters 411, Path: [1 3 3 3 3]
# Iters 412, Path: [1 1 3 1 3]
# Iters 413, Path: [1 3 3 3 3]
# Iters 414, Path: [1 3 3 3 3]
# Iters 415, Path: [1 3 3 3 3]
# Iters 416, Path: [1 1 3 1 3]
# Iters 417, Path: [1 3 3 3 3]
# Iters 418, Path: [1 3 3 3 3]
# Iters 419, Path: [1 3 3 3 3]
# Iters 420, Path: [1 1 3 1 3]
# Iters 421, Path: [1 3 3 3 3]
# Iters 422, Path: [1 3 3 3 3]
# Iters 423, Path: [1 3 3 3 3]
# Iters 424, Path: [1 1 3 1 3]
# Iters 425, Path: [1 3 3 3 3]
# Iters 426, Path: [1 3 3 3 3]
# Iters 427, Path: [1 3 3 3 3]
# Iters 428, Path: [1 1 3 1 3]
# Iters 429, Path: [1 3 3 3 3]
# Iters 430, Path: [1 3 3 3 3]
# Iters 431, Path: [1 3 3 3 3]
# Iters 432, Path: [1 1 3 1 3]
# Iters 433, Path: [1 3 3 3 3]
# Iters 434, Path: [1 3 3 3 3]
# Iters 435, Path: [1 3 3 3 3]
# Iters 436, Path: [1 1 3 1 3]
# Iters 437, Path: [1 3 3 3 3]
# Iters 438, Path: [1 3 3 3 3]
# Iters 439, Path: [1 3 3 3 3]
# Iters 440, Path: [1 1 3 1 3]
# Iters 441, Path: [1 3 3 3 3]
# Iters 442, Path: [1 3 3 3 3]
# Iters 443, Path: [1 3 3 3 3]
# Iters 444, Path: [1 1 3 1 3]
# Iters 445, Path: [1 3 3 3 3]
# Iters 446, Path: [1 3 3 3 3]
# Iters 447, Path: [1 3 3 3 3]
# Iters 448, Path: [1 1 3 1 3]
# Iters 449, Path: [1 3 3 3 3]
# Iters 450, Path: [1 3 3 3 3]
# Iters 451, Path: [1 3 3 3 3]
# Iters 452, Path: [1 1 3 1 3]
# Iters 453, Path: [1 3 3 3 3]
# Iters 454, Path: [1 3 3 3 3]
# Iters 455, Path: [1 3 3 3 3]
# Iters 456, Path: [1 1 3 1 3]
# Iters 457, Path: [1 3 3 3 3]
# Iters 458, Path: [1 3 3 3 3]
# Iters 459, Path: [1 3 3 3 3]
# Iters 460, Path: [1 1 3 1 3]
# Iters 461, Path: [1 3 3 3 3]
# Iters 462, Path: [1 3 3 3 3]
# Iters 463, Path: [1 3 3 3 3]
# Iters 464, Path: [1 1 3 1 3]
# Iters 465, Path: [1 3 3 3 3]
# Iters 466, Path: [1 3 3 3 3]
# Iters 467, Path: [1 3 3 3 3]
# Iters 468, Path: [1 1 3 1 3]
# Iters 469, Path: [1 3 3 3 3]
# Iters 470, Path: [1 3 3 3 3]
# Iters 471, Path: [1 3 3 3 3]
# Iters 472, Path: [1 1 3 1 3]
# Iters 473, Path: [1 3 3 3 3]
# Iters 474, Path: [1 3 3 3 3]
# Iters 475, Path: [1 3 3 3 3]
# Iters 476, Path: [1 1 3 1 3]
# Iters 477, Path: [1 3 3 3 3]
# Iters 478, Path: [1 3 3 3 3]
# Iters 479, Path: [1 3 3 3 3]
# Iters 480, Path: [1 1 3 1 3]
# Iters 481, Path: [1 3 3 3 3]
# Iters 482, Path: [1 3 3 3 3]
# Iters 483, Path: [1 3 3 3 3]
# Iters 484, Path: [1 1 3 1 3]
# Iters 485, Path: [1 3 3 3 3]
# Iters 486, Path: [1 3 3 3 3]
# Iters 487, Path: [1 3 3 3 3]
# Iters 488, Path: [1 1 3 1 3]
# Iters 489, Path: [1 3 3 3 3]
# Iters 490, Path: [1 3 3 3 3]
# Iters 491, Path: [1 3 3 3 3]
# Iters 492, Path: [1 1 3 1 3]
# Iters 493, Path: [1 3 3 3 3]
# Iters 494, Path: [1 3 3 3 3]
# Iters 495, Path: [1 3 3 3 3]
# Iters 496, Path: [1 1 3 1 3]
# Iters 497, Path: [1 3 3 3 3]
# Iters 498, Path: [1 3 3 3 3]
# Iters 499, Path: [1 3 3 3 3]
# Iters 500, Path: [1 1 3 1 3]
# Iters 501, Path: [1 3 3 3 3]
# Iters 502, Path: [1 3 3 3 3]
# Iters 503, Path: [1 3 3 3 3]
# Iters 504, Path: [1 1 3 1 3]
# Iters 505, Path: [1 3 3 3 3]
# Iters 506, Path: [1 3 3 3 3]
# Iters 507, Path: [1 3 3 3 3]
# Iters 508, Path: [1 1 3 1 3]
# Iters 509, Path: [1 3 3 3 3]
# Iters 510, Path: [1 3 3 3 3]
# Iters 511, Path: [1 3 3 3 3]
# Iters 512, Path: [1 1 3 1 3]
# Iters 513, Path: [1 3 3 3 3]
# Iters 514, Path: [1 3 3 3 3]
# Iters 515, Path: [1 3 3 3 3]
# Iters 516, Path: [1 1 3 1 3]
# Iters 517, Path: [1 3 3 3 3]
# Iters 518, Path: [1 3 3 3 3]
# Iters 519, Path: [1 3 3 3 3]
# Iters 520, Path: [1 1 3 1 3]
# Iters 521, Path: [1 3 3 3 3]
# Iters 522, Path: [1 3 3 3 3]
# Iters 523, Path: [1 3 3 3 3]
# Iters 524, Path: [1 1 3 1 3]
# Iters 525, Path: [1 3 3 3 3]
# Iters 526, Path: [1 3 3 3 3]
# Iters 527, Path: [1 3 3 3 3]
# Iters 528, Path: [1 1 3 1 3]
# Iters 529, Path: [1 3 3 3 3]
# Iters 530, Path: [1 3 3 3 3]
# Iters 531, Path: [1 3 3 3 3]
# Iters 532, Path: [1 1 3 1 3]
# Iters 533, Path: [1 3 3 3 3]
# Iters 534, Path: [1 3 3 3 3]
# Iters 535, Path: [1 3 3 3 3]
# Iters 536, Path: [1 1 3 1 3]
# Iters 537, Path: [1 3 3 3 3]
# Iters 538, Path: [1 3 3 3 3]
# Iters 539, Path: [1 3 3 3 3]
# Iters 540, Path: [1 1 3 1 3]
# Iters 541, Path: [1 3 3 3 3]
# Iters 542, Path: [1 3 3 3 3]
# Iters 543, Path: [1 3 3 3 3]
# Iters 544, Path: [1 1 3 1 3]
# Iters 545, Path: [1 3 3 3 3]
# Iters 546, Path: [1 3 3 3 3]
# Iters 547, Path: [1 3 3 3 3]
# Iters 548, Path: [1 1 3 1 3]
# Iters 549, Path: [1 3 3 3 3]
# Iters 550, Path: [1 3 3 3 3]
# Iters 551, Path: [1 3 3 3 3]
# Iters 552, Path: [1 1 3 1 3]
# Iters 553, Path: [1 3 3 3 3]
# Iters 554, Path: [1 3 3 3 3]
# Iters 555, Path: [1 3 3 3 3]
# Iters 556, Path: [1 1 3 1 3]
# Iters 557, Path: [1 3 3 3 3]
# Iters 558, Path: [1 3 3 3 3]
# Iters 559, Path: [1 3 3 3 3]
# Iters 560, Path: [1 1 3 1 3]
# Iters 561, Path: [1 3 3 3 3]
# Iters 562, Path: [1 3 3 3 3]
# Iters 563, Path: [1 3 3 3 3]
# Iters 564, Path: [1 1 3 1 3]
# Iters 565, Path: [1 3 3 3 3]
# Iters 566, Path: [1 3 3 3 3]
# Iters 567, Path: [1 3 3 3 3]
# Iters 568, Path: [1 1 3 1 3]
# Iters 569, Path: [1 3 3 3 3]
# Iters 570, Path: [1 3 3 3 3]
# Iters 571, Path: [1 3 3 3 3]
# Iters 572, Path: [1 1 3 1 3]
# Iters 573, Path: [1 3 3 3 3]
# Iters 574, Path: [1 3 3 3 3]
# Iters 575, Path: [1 3 3 3 3]
# Iters 576, Path: [1 1 3 1 3]
# Iters 577, Path: [1 3 3 3 3]
# Iters 578, Path: [1 3 3 3 3]
# Iters 579, Path: [1 3 3 3 3]
# Iters 580, Path: [1 1 3 1 3]
# Iters 581, Path: [1 3 3 3 3]
# Iters 582, Path: [1 3 3 3 3]
# Iters 583, Path: [1 3 3 3 3]
# Iters 584, Path: [1 1 3 1 3]
# Iters 585, Path: [1 3 3 3 3]
# Iters 586, Path: [1 3 3 3 3]
# Iters 587, Path: [1 3 3 3 3]
# Iters 588, Path: [1 1 3 1 3]
# Iters 589, Path: [1 3 3 3 3]
# Iters 590, Path: [1 3 3 3 3]
# Iters 591, Path: [1 3 3 3 3]
# Iters 592, Path: [1 1 3 1 3]
# Iters 593, Path: [1 3 3 3 3]
# Iters 594, Path: [1 3 3 3 3]
# Iters 595, Path: [1 3 3 3 3]
# Iters 596, Path: [1 1 3 1 3]
# Iters 597, Path: [1 3 3 3 3]
# Iters 598, Path: [1 3 3 3 3]
# Iters 599, Path: [1 3 3 3 3]
# Iters 600, Path: [1 1 3 1 3]
# Iters 601, Path: [1 3 3 3 3]
# Iters 602, Path: [1 3 3 3 3]
# Iters 603, Path: [1 3 3 3 3]
# Iters 604, Path: [1 1 3 1 3]
# Iters 605, Path: [1 3 3 3 3]
# Iters 606, Path: [1 3 3 3 3]
# Iters 607, Path: [1 3 3 3 3]
# Iters 608, Path: [1 1 3 1 3]
# Iters 609, Path: [1 3 3 3 3]
# Iters 610, Path: [1 3 3 3 3]
# Iters 611, Path: [1 3 3 3 3]
# Iters 612, Path: [1 1 3 1 3]
# Iters 613, Path: [1 3 3 3 3]
# Iters 614, Path: [1 3 3 3 3]
# Iters 615, Path: [1 3 3 3 3]
# Iters 616, Path: [1 1 3 1 3]
# Iters 617, Path: [1 3 3 3 3]
# Iters 618, Path: [1 3 3 3 3]
# Iters 619, Path: [1 3 3 3 3]
# Iters 620, Path: [1 1 3 1 3]
# Iters 621, Path: [1 3 3 3 3]
# Iters 622, Path: [1 3 3 3 3]
# Iters 623, Path: [1 3 3 3 3]
# Iters 624, Path: [1 1 3 1 3]
# Iters 625, Path: [1 3 3 3 3]
# Iters 626, Path: [1 3 3 3 3]
# Iters 627, Path: [1 3 3 3 3]
# Iters 628, Path: [1 1 3 1 3]
# Iters 629, Path: [1 3 3 3 3]
# Iters 630, Path: [1 3 3 3 3]
# Iters 631, Path: [1 3 3 3 3]
# Iters 632, Path: [1 1 3 1 3]
# Iters 633, Path: [1 3 3 3 3]
# Iters 634, Path: [1 3 3 3 3]
# Iters 635, Path: [1 3 3 3 3]
# Iters 636, Path: [1 1 3 1 3]
# Iters 637, Path: [1 3 3 3 3]
# Iters 638, Path: [1 3 3 3 3]
# Iters 639, Path: [1 3 3 3 3]
# Iters 640, Path: [1 1 3 1 3]
# Iters 641, Path: [1 3 3 3 3]
# Iters 642, Path: [1 3 3 3 3]
# Iters 643, Path: [1 3 3 3 3]
# Iters 644, Path: [1 1 3 1 3]
# Iters 645, Path: [1 3 3 3 3]
# Iters 646, Path: [1 3 3 3 3]
# Iters 647, Path: [1 3 3 3 3]
# Iters 648, Path: [1 1 3 1 3]
# Iters 649, Path: [1 3 3 3 3]
# Iters 650, Path: [1 3 3 3 3]
# Iters 651, Path: [1 3 3 3 3]
# Iters 652, Path: [1 1 3 1 3]
# Iters 653, Path: [1 3 3 3 3]
# Iters 654, Path: [1 3 3 3 3]
# Iters 655, Path: [1 3 3 3 3]
# Iters 656, Path: [1 1 3 1 3]
# Iters 657, Path: [1 3 3 3 3]
# Iters 658, Path: [1 3 3 3 3]
# Iters 659, Path: [1 3 3 3 3]
# Iters 660, Path: [1 1 3 1 3]
# Iters 661, Path: [1 3 3 3 3]
# Iters 662, Path: [1 3 3 3 3]
# Iters 663, Path: [1 3 3 3 3]
# Iters 664, Path: [1 1 3 1 3]
# Iters 665, Path: [1 3 3 3 3]
# Iters 666, Path: [1 3 3 3 3]
# Iters 667, Path: [1 3 3 3 3]
# Iters 668, Path: [1 1 3 1 3]
# Iters 669, Path: [1 3 3 3 3]
# Iters 670, Path: [1 3 3 3 3]
# Iters 671, Path: [1 3 3 3 3]
# Iters 672, Path: [1 1 3 1 3]
# Iters 673, Path: [1 3 3 3 3]
# Iters 674, Path: [1 3 3 3 3]
# Iters 675, Path: [1 3 3 3 3]
# Iters 676, Path: [1 1 3 1 3]
# Iters 677, Path: [1 3 3 3 3]
# Iters 678, Path: [1 3 3 3 3]
# Iters 679, Path: [1 3 3 3 3]
# Iters 680, Path: [1 1 3 1 3]
# Iters 681, Path: [1 3 3 3 3]
# Iters 682, Path: [1 3 3 3 3]
# Iters 683, Path: [1 3 3 3 3]
# Iters 684, Path: [1 1 3 1 3]
# Iters 685, Path: [1 3 3 3 3]
# Iters 686, Path: [1 3 3 3 3]
# Iters 687, Path: [1 3 3 3 3]
# Iters 688, Path: [1 1 3 1 3]
# Iters 689, Path: [1 3 3 3 3]
# Iters 690, Path: [1 3 3 3 3]
# Iters 691, Path: [1 3 3 3 3]
# Iters 692, Path: [1 1 3 1 3]
# Iters 693, Path: [1 3 3 3 3]
# Iters 694, Path: [1 3 3 3 3]
# Iters 695, Path: [1 3 3 3 3]
# Iters 696, Path: [1 1 3 1 3]
# Iters 697, Path: [1 3 3 3 3]
# Iters 698, Path: [1 3 3 3 3]
# Iters 699, Path: [1 3 3 3 3]
# Iters 700, Path: [1 1 3 1 3]
# Iters 701, Path: [1 3 3 3 3]
# Iters 702, Path: [1 3 3 3 3]
# Iters 703, Path: [1 3 3 3 3]
# Iters 704, Path: [1 1 3 1 3]
# Iters 705, Path: [1 3 3 3 3]
# Iters 706, Path: [1 3 3 3 3]
# Iters 707, Path: [1 3 3 3 3]
# Iters 708, Path: [1 1 3 1 3]
# Iters 709, Path: [1 3 3 3 3]
# Iters 710, Path: [1 3 3 3 3]
# Iters 711, Path: [1 3 3 3 3]
# Iters 712, Path: [1 1 3 1 3]
# Iters 713, Path: [1 3 3 3 3]
# Iters 714, Path: [1 3 3 3 3]
# Iters 715, Path: [1 3 3 3 3]
# Iters 716, Path: [1 1 3 1 3]
# Iters 717, Path: [1 3 3 3 3]
# Iters 718, Path: [1 3 3 3 3]
# Iters 719, Path: [1 3 3 3 3]
# Iters 720, Path: [1 1 3 1 3]
# Iters 721, Path: [1 3 3 3 3]
# Iters 722, Path: [1 3 3 3 3]
# Iters 723, Path: [1 3 3 3 3]
# Iters 724, Path: [1 1 3 1 3]
# Iters 725, Path: [1 3 3 3 3]
# Iters 726, Path: [1 3 3 3 3]
# Iters 727, Path: [1 3 3 3 3]
# Iters 728, Path: [1 1 3 1 3]
# Iters 729, Path: [1 3 3 3 3]
# Iters 730, Path: [1 3 3 3 3]
# Iters 731, Path: [1 3 3 3 3]
# Iters 732, Path: [1 1 3 1 3]
# Iters 733, Path: [1 3 3 3 3]
# Iters 734, Path: [1 3 3 3 3]
# Iters 735, Path: [1 3 3 3 3]
# Iters 736, Path: [1 1 3 1 3]
# Iters 737, Path: [1 3 3 3 3]
# Iters 738, Path: [1 3 3 3 3]
# Iters 739, Path: [1 3 3 3 3]
# Iters 740, Path: [1 1 3 1 3]
# Iters 741, Path: [1 3 3 3 3]
# Iters 742, Path: [1 3 3 3 3]
# Iters 743, Path: [1 3 3 3 3]
# Iters 744, Path: [1 1 3 1 3]
# Iters 745, Path: [1 3 3 3 3]
# Iters 746, Path: [1 3 3 3 3]
# Iters 747, Path: [1 3 3 3 3]
# Iters 748, Path: [1 1 3 1 3]
# Iters 749, Path: [1 3 3 3 3]
# Iters 750, Path: [1 3 3 3 3]
# Iters 751, Path: [1 3 3 3 3]
# Iters 752, Path: [1 1 3 1 3]
# Iters 753, Path: [1 3 3 3 3]
# Iters 754, Path: [1 3 3 3 3]
# Iters 755, Path: [1 3 3 3 3]
# Iters 756, Path: [1 1 3 1 3]
# Iters 757, Path: [1 3 3 3 3]
# Iters 758, Path: [1 3 3 3 3]
# Iters 759, Path: [1 3 3 3 3]
# Iters 760, Path: [1 1 3 1 3]
# Iters 761, Path: [1 3 3 3 3]
# Iters 762, Path: [1 3 3 3 3]
# Iters 763, Path: [1 3 3 3 3]
# Iters 764, Path: [1 1 3 1 3]
# Iters 765, Path: [1 3 3 3 3]
# Iters 766, Path: [1 3 3 3 3]
# Iters 767, Path: [1 3 3 3 3]
# Iters 768, Path: [1 1 3 1 3]
# Iters 769, Path: [1 3 3 3 3]
# Iters 770, Path: [1 3 3 3 3]
# Iters 771, Path: [1 3 3 3 3]
# Iters 772, Path: [1 1 3 1 3]
# Iters 773, Path: [1 3 3 3 3]
# Iters 774, Path: [1 3 3 3 3]
# Iters 775, Path: [1 3 3 3 3]
# Iters 776, Path: [1 1 3 1 3]
# Iters 777, Path: [1 3 3 3 3]
# Iters 778, Path: [1 3 3 3 3]
# Iters 779, Path: [1 3 3 3 3]
# Iters 780, Path: [1 1 3 1 3]
# Iters 781, Path: [1 3 3 3 3]
# Iters 782, Path: [1 3 3 3 3]
# Iters 783, Path: [1 3 3 3 3]
# Iters 784, Path: [1 1 3 1 3]
# Iters 785, Path: [1 3 3 3 3]
# Iters 786, Path: [1 3 3 3 3]
# Iters 787, Path: [1 3 3 3 3]
# Iters 788, Path: [1 1 3 1 3]
# Iters 789, Path: [1 3 3 3 3]
# Iters 790, Path: [1 3 3 3 3]
# Iters 791, Path: [1 3 3 3 3]
# Iters 792, Path: [1 1 3 1 3]
# Iters 793, Path: [1 3 3 3 3]
# Iters 794, Path: [1 3 3 3 3]
# Iters 795, Path: [1 3 3 3 3]
# Iters 796, Path: [1 1 3 1 3]
# Iters 797, Path: [1 3 3 3 3]
# Iters 798, Path: [1 3 3 3 3]
# Iters 799, Path: [1 3 3 3 3]
# Iters 800, Path: [1 1 3 1 3]
# Iters 801, Path: [1 3 3 3 3]
# Iters 802, Path: [1 3 3 3 3]
# Iters 803, Path: [1 3 3 3 3]
# Iters 804, Path: [1 1 3 1 3]
# Iters 805, Path: [1 3 3 3 3]
# Iters 806, Path: [1 3 3 3 3]
# Iters 807, Path: [1 3 3 3 3]
# Iters 808, Path: [1 1 3 1 3]
# Iters 809, Path: [1 3 3 3 3]
# Iters 810, Path: [1 3 3 3 3]
# Iters 811, Path: [1 3 3 3 3]
# Iters 812, Path: [1 1 3 1 3]
# Iters 813, Path: [1 3 3 3 3]
# Iters 814, Path: [1 3 3 3 3]
# Iters 815, Path: [1 3 3 3 3]
# Iters 816, Path: [1 1 3 1 3]
# Iters 817, Path: [1 3 3 3 3]
# Iters 818, Path: [1 3 3 3 3]
# Iters 819, Path: [1 3 3 3 3]
# Iters 820, Path: [1 1 3 1 3]
# Iters 821, Path: [1 3 3 3 3]
# Iters 822, Path: [1 3 3 3 3]
# Iters 823, Path: [1 3 3 3 3]
# Iters 824, Path: [1 1 3 1 3]
# Iters 825, Path: [1 3 3 3 3]
# Iters 826, Path: [1 3 3 3 3]
# Iters 827, Path: [1 3 3 3 3]
# Iters 828, Path: [1 1 3 1 3]
# Iters 829, Path: [1 3 3 3 3]
# Iters 830, Path: [1 3 3 3 3]
# Iters 831, Path: [1 3 3 3 3]
# Iters 832, Path: [1 1 3 1 3]
# Iters 833, Path: [1 3 3 3 3]
# Iters 834, Path: [1 3 3 3 3]
# Iters 835, Path: [1 3 3 3 3]
# Iters 836, Path: [1 1 3 1 3]
# Iters 837, Path: [1 3 3 3 3]
# Iters 838, Path: [1 3 3 3 3]
# Iters 839, Path: [1 3 3 3 3]
# Iters 840, Path: [1 1 3 1 3]
# Iters 841, Path: [1 3 3 3 3]
# Iters 842, Path: [1 3 3 3 3]
# Iters 843, Path: [1 3 3 3 3]
# Iters 844, Path: [1 1 3 1 3]
# Iters 845, Path: [1 3 3 3 3]
# Iters 846, Path: [1 3 3 3 3]
# Iters 847, Path: [1 3 3 3 3]
# Iters 848, Path: [1 1 3 1 3]
# Iters 849, Path: [1 3 3 3 3]
# Iters 850, Path: [1 3 3 3 3]
# Iters 851, Path: [1 3 3 3 3]
# Iters 852, Path: [1 1 3 1 3]
# Iters 853, Path: [1 3 3 3 3]
# Iters 854, Path: [1 3 3 3 3]
# Iters 855, Path: [1 3 3 3 3]
# Iters 856, Path: [1 1 3 1 3]
# Iters 857, Path: [1 3 3 3 3]
# Iters 858, Path: [1 3 3 3 3]
# Iters 859, Path: [1 3 3 3 3]
# Iters 860, Path: [1 1 3 1 3]
# Iters 861, Path: [1 3 3 3 3]
# Iters 862, Path: [1 3 3 3 3]
# Iters 863, Path: [1 3 3 3 3]
# Iters 864, Path: [1 1 3 1 3]
# Iters 865, Path: [1 3 3 3 3]
# Iters 866, Path: [1 3 3 3 3]
# Iters 867, Path: [1 3 3 3 3]
# Iters 868, Path: [1 1 3 1 3]
# Iters 869, Path: [1 3 3 3 3]
# Iters 870, Path: [1 3 3 3 3]
# Iters 871, Path: [1 3 3 3 3]
# Iters 872, Path: [1 1 3 1 3]
# Iters 873, Path: [1 3 3 3 3]
# Iters 874, Path: [1 3 3 3 3]
# Iters 875, Path: [1 3 3 3 3]
# Iters 876, Path: [1 1 3 1 3]
# Iters 877, Path: [1 3 3 3 3]
# Iters 878, Path: [1 3 3 3 3]
# Iters 879, Path: [1 3 3 3 3]
# Iters 880, Path: [1 1 3 1 3]
# Iters 881, Path: [1 3 3 3 3]
# Iters 882, Path: [1 3 3 3 3]
# Iters 883, Path: [1 3 3 3 3]
# Iters 884, Path: [1 1 3 1 3]
# Iters 885, Path: [1 3 3 3 3]
# Iters 886, Path: [1 3 3 3 3]
# Iters 887, Path: [1 3 3 3 3]
# Iters 888, Path: [1 1 3 1 3]
# Iters 889, Path: [1 3 3 3 3]
# Iters 890, Path: [1 3 3 3 3]
# Iters 891, Path: [1 3 3 3 3]
# Iters 892, Path: [1 1 3 1 3]
# Iters 893, Path: [1 3 3 3 3]
# Iters 894, Path: [1 3 3 3 3]
# Iters 895, Path: [1 3 3 3 3]
# Iters 896, Path: [1 1 3 1 3]
# Iters 897, Path: [1 3 3 3 3]
# Iters 898, Path: [1 3 3 3 3]
# Iters 899, Path: [1 3 3 3 3]
# Iters 900, Path: [1 1 3 1 3]
# Iters 901, Path: [1 3 3 3 3]
# Iters 902, Path: [1 3 3 3 3]
# Iters 903, Path: [1 3 3 3 3]
# Iters 904, Path: [1 1 3 1 3]
# Iters 905, Path: [1 3 3 3 3]
# Iters 906, Path: [1 3 3 3 3]
# Iters 907, Path: [1 3 3 3 3]
# Iters 908, Path: [1 1 3 1 3]
# Iters 909, Path: [1 3 3 3 3]
# Iters 910, Path: [1 3 3 3 3]
# Iters 911, Path: [1 3 3 3 3]
# Iters 912, Path: [1 1 3 1 3]
# Iters 913, Path: [1 3 3 3 3]
# Iters 914, Path: [1 3 3 3 3]
# Iters 915, Path: [1 3 3 3 3]
# Iters 916, Path: [1 1 3 1 3]
# Iters 917, Path: [1 3 3 3 3]
# Iters 918, Path: [1 3 3 3 3]
# Iters 919, Path: [1 3 3 3 3]
# Iters 920, Path: [1 1 3 1 3]
# Iters 921, Path: [1 3 3 3 3]
# Iters 922, Path: [1 3 3 3 3]
# Iters 923, Path: [1 3 3 3 3]
# Iters 924, Path: [1 1 3 1 3]
# Iters 925, Path: [1 3 3 3 3]
# Iters 926, Path: [1 3 3 3 3]
# Iters 927, Path: [1 3 3 3 3]
# Iters 928, Path: [1 1 3 1 3]
# Iters 929, Path: [1 3 3 3 3]
# Iters 930, Path: [1 3 3 3 3]
# Iters 931, Path: [1 3 3 3 3]
# Iters 932, Path: [1 1 3 1 3]
# Iters 933, Path: [1 3 3 3 3]
# Iters 934, Path: [1 3 3 3 3]
# Iters 935, Path: [1 3 3 3 3]
# Iters 936, Path: [1 1 3 1 3]
# Iters 937, Path: [1 3 3 3 3]
# Iters 938, Path: [1 3 3 3 3]
# Iters 939, Path: [1 3 3 3 3]
# Iters 940, Path: [1 1 3 1 3]
# Iters 941, Path: [1 3 3 3 3]
# Iters 942, Path: [1 3 3 3 3]
# Iters 943, Path: [1 3 3 3 3]
# Iters 944, Path: [1 1 3 1 3]
# Iters 945, Path: [1 3 3 3 3]
# Iters 946, Path: [1 3 3 3 3]
# Iters 947, Path: [1 3 3 3 3]
# Iters 948, Path: [1 1 3 1 3]
# Iters 949, Path: [1 3 3 3 3]
# Iters 950, Path: [1 3 3 3 3]
# Iters 951, Path: [1 3 3 3 3]
# Iters 952, Path: [1 1 3 1 3]
# Iters 953, Path: [1 3 3 3 3]
# Iters 954, Path: [1 3 3 3 3]
# Iters 955, Path: [1 3 3 3 3]
# Iters 956, Path: [1 1 3 1 3]
# Iters 957, Path: [1 3 3 3 3]
# Iters 958, Path: [1 3 3 3 3]
# Iters 959, Path: [1 3 3 3 3]
# Iters 960, Path: [1 1 3 1 3]
# Iters 961, Path: [1 3 3 3 3]
# Iters 962, Path: [1 3 3 3 3]
# Iters 963, Path: [1 3 3 3 3]
# Iters 964, Path: [1 1 3 1 3]
# Iters 965, Path: [1 3 3 3 3]
# Iters 966, Path: [1 3 3 3 3]
# Iters 967, Path: [1 3 3 3 3]
# Iters 968, Path: [1 1 3 1 3]
# Iters 969, Path: [1 3 3 3 3]
# Iters 970, Path: [1 3 3 3 3]
# Iters 971, Path: [1 3 3 3 3]
# Iters 972, Path: [1 1 3 1 3]
# Iters 973, Path: [1 3 3 3 3]
# Iters 974, Path: [1 3 3 3 3]
# Iters 975, Path: [1 3 3 3 3]
# Iters 976, Path: [1 1 3 1 3]
# Iters 977, Path: [1 3 3 3 3]
# Iters 978, Path: [1 3 3 3 3]
# Iters 979, Path: [1 3 3 3 3]
# Iters 980, Path: [1 1 3 1 3]
# Iters 981, Path: [1 3 3 3 3]
# Iters 982, Path: [1 3 3 3 3]
# Iters 983, Path: [1 3 3 3 3]
# Iters 984, Path: [1 1 3 1 3]
# Iters 985, Path: [1 3 3 3 3]
# Iters 986, Path: [1 3 3 3 3]
# Iters 987, Path: [1 3 3 3 3]
# Iters 988, Path: [1 1 3 1 3]
# Iters 989, Path: [1 3 3 3 3]
# Iters 990, Path: [1 3 3 3 3]
# Iters 991, Path: [1 3 3 3 3]
# Iters 992, Path: [1 1 3 1 3]
# Iters 993, Path: [1 3 3 3 3]
# Iters 994, Path: [1 3 3 3 3]
# Iters 995, Path: [1 3 3 3 3]
# Iters 996, Path: [1 1 3 1 3]
# Iters 997, Path: [1 3 3 3 3]
# Iters 998, Path: [1 3 3 3 3]
# Iters 999, Path: [1 3 3 3 3]
# Iters 1000, Path: [1 1 3 1 3]
# Iters 1001, Path: [1 3 3 3 3]
# Iters 1002, Path: [1 3 3 3 3]
# Iters 1003, Path: [1 3 3 3 3]
# Iters 1004, Path: [1 1 3 1 3]
# Iters 1005, Path: [1 3 3 3 3]
# Iters 1006, Path: [1 3 3 3 3]
# Iters 1007, Path: [1 3 3 3 3]
# Iters 1008, Path: [1 1 3 1 3]
# Iters 1009, Path: [1 3 3 3 3]
# Iters 1010, Path: [1 3 3 3 3]
# Iters 1011, Path: [1 3 3 3 3]
# Iters 1012, Path: [1 1 3 1 3]
# Iters 1013, Path: [1 3 3 3 3]
# Iters 1014, Path: [1 3 3 3 3]
# Iters 1015, Path: [1 3 3 3 3]
# Iters 1016, Path: [1 1 3 1 3]
# Iters 1017, Path: [1 3 3 3 3]
# Iters 1018, Path: [1 3 3 3 3]
# Iters 1019, Path: [1 3 3 3 3]
# Iters 1020, Path: [1 1 3 1 3]
# Iters 1021, Path: [1 3 3 3 3]
# Iters 1022, Path: [1 3 3 3 3]
# Iters 1023, Path: [1 3 3 3 3]
# Iters 1024, Path: [1 1 3 1 3]
# Iters 1025, Path: [1 3 3 3 3]
# Iters 1026, Path: [1 3 3 3 3]
# Iters 1027, Path: [1 3 3 3 3]
# Iters 1028, Path: [1 1 3 1 3]
# Iters 1029, Path: [1 3 3 3 3]
# Iters 1030, Path: [1 3 3 3 3]
# Iters 1031, Path: [1 3 3 3 3]
# Iters 1032, Path: [1 1 3 1 3]
# Iters 1033, Path: [1 3 3 3 3]
# Iters 1034, Path: [1 3 3 3 3]
# Iters 1035, Path: [1 3 3 3 3]
# Iters 1036, Path: [1 1 3 1 3]
# Iters 1037, Path: [1 3 3 3 3]
# Iters 1038, Path: [1 3 3 3 3]
# Iters 1039, Path: [1 3 3 3 3]
# Iters 1040, Path: [1 1 3 1 3]
# Iters 1041, Path: [1 3 3 3 3]
# Iters 1042, Path: [1 3 3 3 3]
# Iters 1043, Path: [1 3 3 3 3]
# Iters 1044, Path: [1 1 3 1 3]
# Iters 1045, Path: [1 3 3 3 3]
# Iters 1046, Path: [1 3 3 3 3]
# Iters 1047, Path: [1 3 3 3 3]
# Iters 1048, Path: [1 1 3 1 3]
# Iters 1049, Path: [1 3 3 3 3]
# Iters 1050, Path: [1 3 3 3 3]
# Iters 1051, Path: [1 3 3 3 3]
# Iters 1052, Path: [1 1 3 1 3]
# Iters 1053, Path: [1 3 3 3 3]
# Iters 1054, Path: [1 3 3 3 3]
# Iters 1055, Path: [1 3 3 3 3]
# Iters 1056, Path: [1 1 3 1 3]
# Iters 1057, Path: [1 3 3 3 3]
# Iters 1058, Path: [1 3 3 3 3]
# Iters 1059, Path: [1 3 3 3 3]
# Iters 1060, Path: [1 1 3 1 3]
# Iters 1061, Path: [1 3 3 3 3]
# Iters 1062, Path: [1 3 3 3 3]
# Iters 1063, Path: [1 3 3 3 3]
# Iters 1064, Path: [1 1 3 1 3]
# Iters 1065, Path: [1 3 3 3 3]
# Iters 1066, Path: [1 3 3 3 3]
# Iters 1067, Path: [1 3 3 3 3]
# Iters 1068, Path: [1 1 3 1 3]
# Iters 1069, Path: [1 3 3 3 3]
# Iters 1070, Path: [1 3 3 3 3]
# Iters 1071, Path: [1 3 3 3 3]
# Iters 1072, Path: [1 1 3 1 3]
# Iters 1073, Path: [1 3 3 3 3]
# Iters 1074, Path: [1 3 3 3 3]
# Iters 1075, Path: [1 3 3 3 3]
# Iters 1076, Path: [1 1 3 1 3]
# Iters 1077, Path: [1 3 3 3 3]
# Iters 1078, Path: [1 3 3 3 3]
# Iters 1079, Path: [1 3 3 3 3]
# Iters 1080, Path: [1 1 3 1 3]
# Iters 1081, Path: [1 3 3 3 3]
# Iters 1082, Path: [1 3 3 3 3]
# Iters 1083, Path: [1 3 3 3 3]
# Iters 1084, Path: [1 1 3 1 3]
# Iters 1085, Path: [1 3 3 3 3]
# Iters 1086, Path: [1 3 3 3 3]
# Iters 1087, Path: [1 3 3 3 3]
# Iters 1088, Path: [1 1 3 1 3]
# Iters 1089, Path: [1 3 3 3 3]
# Iters 1090, Path: [1 3 3 3 3]
# Iters 1091, Path: [1 3 3 3 3]
# Iters 1092, Path: [1 1 3 1 3]
# Iters 1093, Path: [1 3 3 3 3]
# Iters 1094, Path: [1 3 3 3 3]
# Iters 1095, Path: [1 3 3 3 3]
# Iters 1096, Path: [1 1 3 1 3]
# Iters 1097, Path: [1 3 3 3 3]
# Iters 1098, Path: [1 3 3 3 3]
# Iters 1099, Path: [1 3 3 3 3]
# Iters 1100, Path: [1 1 3 1 3]
# Iters 1101, Path: [1 3 3 3 3]
# Iters 1102, Path: [1 3 3 3 3]
# Iters 1103, Path: [1 3 3 3 3]
# Iters 1104, Path: [1 1 3 1 3]
# Iters 1105, Path: [1 3 3 3 3]
# Iters 1106, Path: [1 3 3 3 3]
# Iters 1107, Path: [1 3 3 3 3]
# Iters 1108, Path: [1 1 3 1 3]
# Iters 1109, Path: [1 3 3 3 3]
# Iters 1110, Path: [1 3 3 3 3]
# Iters 1111, Path: [1 3 3 3 3]
# Iters 1112, Path: [1 1 3 1 3]
# Iters 1113, Path: [1 3 3 3 3]
# Iters 1114, Path: [1 3 3 3 3]
# Iters 1115, Path: [1 3 3 3 3]
# Iters 1116, Path: [1 1 3 1 3]
# Iters 1117, Path: [1 3 3 3 3]
# Iters 1118, Path: [1 3 3 3 3]
# Iters 1119, Path: [1 3 3 3 3]
# Iters 1120, Path: [1 1 3 1 3]
# Iters 1121, Path: [1 3 3 3 3]
# Iters 1122, Path: [1 3 3 3 3]
# Iters 1123, Path: [1 3 3 3 3]
# Iters 1124, Path: [1 1 3 1 3]
# Iters 1125, Path: [1 3 3 3 3]
# Iters 1126, Path: [1 3 3 3 3]
# Iters 1127, Path: [1 3 3 3 3]
# Iters 1128, Path: [1 1 3 1 3]
# Iters 1129, Path: [1 3 3 3 3]
# Iters 1130, Path: [1 3 3 3 3]
# Iters 1131, Path: [1 3 3 3 3]
# Iters 1132, Path: [1 1 3 1 3]
# Iters 1133, Path: [1 3 3 3 3]
# Iters 1134, Path: [1 3 3 3 3]
# Iters 1135, Path: [1 3 3 3 3]
# Iters 1136, Path: [1 1 3 1 3]
# Iters 1137, Path: [1 3 3 3 3]
# Iters 1138, Path: [1 3 3 3 3]
# Iters 1139, Path: [1 3 3 3 3]
# Iters 1140, Path: [1 1 3 1 3]
# Iters 1141, Path: [1 3 3 3 3]
# Iters 1142, Path: [1 3 3 3 3]
# Iters 1143, Path: [1 3 3 3 3]
# Iters 1144, Path: [1 1 3 1 3]
# Iters 1145, Path: [1 3 3 3 3]
# Iters 1146, Path: [1 3 3 3 3]
# Iters 1147, Path: [1 3 3 3 3]
# Iters 1148, Path: [1 1 3 1 3]
# Iters 1149, Path: [1 3 3 3 3]
# Iters 1150, Path: [1 3 3 3 3]
# Iters 1151, Path: [1 3 3 3 3]
# Iters 1152, Path: [1 1 3 1 3]
# Iters 1153, Path: [1 3 3 3 3]
# Iters 1154, Path: [1 3 3 3 3]
# Iters 1155, Path: [1 3 3 3 3]
# Iters 1156, Path: [1 1 3 1 3]
# Iters 1157, Path: [1 3 3 3 3]
# Iters 1158, Path: [1 3 3 3 3]
# Iters 1159, Path: [1 3 3 3 3]
# Iters 1160, Path: [1 1 3 1 3]
# Iters 1161, Path: [1 3 3 3 3]
# Iters 1162, Path: [1 3 3 3 3]
# Iters 1163, Path: [1 3 3 3 3]
# Iters 1164, Path: [1 1 3 1 3]
# Iters 1165, Path: [1 3 3 3 3]
# Iters 1166, Path: [1 3 3 3 3]
# Iters 1167, Path: [1 3 3 3 3]
# Iters 1168, Path: [1 1 3 1 3]
# Iters 1169, Path: [1 3 3 3 3]
# Iters 1170, Path: [1 3 3 3 3]
# Iters 1171, Path: [1 3 3 3 3]
# Iters 1172, Path: [1 1 3 1 3]
# Iters 1173, Path: [1 3 3 3 3]
# Iters 1174, Path: [1 3 3 3 3]
# Iters 1175, Path: [1 3 3 3 3]
# Iters 1176, Path: [1 1 3 1 3]
# Iters 1177, Path: [1 3 3 3 3]
# Iters 1178, Path: [1 3 3 3 3]
# Iters 1179, Path: [1 3 3 3 3]
# Iters 1180, Path: [1 1 3 1 3]
# Iters 1181, Path: [1 3 3 3 3]
# Iters 1182, Path: [1 3 3 3 3]
# Iters 1183, Path: [1 3 3 3 3]
# Iters 1184, Path: [1 1 3 1 3]
# Iters 1185, Path: [1 3 3 3 3]
# Iters 1186, Path: [1 3 3 3 3]
# Iters 1187, Path: [1 3 3 3 3]
# Iters 1188, Path: [1 1 3 1 3]
# Iters 1189, Path: [1 3 3 3 3]
# Iters 1190, Path: [1 3 3 3 3]
# Iters 1191, Path: [1 3 3 3 3]
# Iters 1192, Path: [1 1 3 1 3]
# Iters 1193, Path: [1 3 3 3 3]
# Iters 1194, Path: [1 3 3 3 3]
# Iters 1195, Path: [1 3 3 3 3]
# Iters 1196, Path: [1 1 3 1 3]
# Iters 1197, Path: [1 3 3 3 3]
# Iters 1198, Path: [1 3 3 3 3]
# Iters 1199, Path: [1 3 3 3 3]
# Iters 1200, Path: [1 1 3 1 3]
# Iters 1201, Path: [1 3 3 3 3]
# Iters 1202, Path: [1 3 3 3 3]
# Iters 1203, Path: [1 3 3 3 3]
# Iters 1204, Path: [1 1 3 1 3]
# Iters 1205, Path: [1 3 3 3 3]
# Iters 1206, Path: [1 3 3 3 3]
# Iters 1207, Path: [1 3 3 3 3]
# Iters 1208, Path: [1 1 3 1 3]
# Iters 1209, Path: [1 3 3 3 3]
# Iters 1210, Path: [1 3 3 3 3]
# Iters 1211, Path: [1 3 3 3 3]
# Iters 1212, Path: [1 1 3 1 3]
# Iters 1213, Path: [1 3 3 3 3]
# Iters 1214, Path: [1 3 3 3 3]
# Iters 1215, Path: [1 3 3 3 3]
# Iters 1216, Path: [1 1 3 1 3]
# Iters 1217, Path: [1 3 3 3 3]
# Iters 1218, Path: [1 3 3 3 3]
# Iters 1219, Path: [1 3 3 3 3]
# Iters 1220, Path: [1 1 3 1 3]
# Iters 1221, Path: [1 3 3 3 3]
# Iters 1222, Path: [1 3 3 3 3]
# Iters 1223, Path: [1 3 3 3 3]
# Iters 1224, Path: [1 1 3 1 3]
# Iters 1225, Path: [1 3 3 3 3]
# Iters 1226, Path: [1 3 3 3 3]
# Iters 1227, Path: [1 3 3 3 3]
# Iters 1228, Path: [1 1 3 1 3]
# Iters 1229, Path: [1 3 3 3 3]
# Iters 1230, Path: [1 3 3 3 3]
# Iters 1231, Path: [1 3 3 3 3]
# Iters 1232, Path: [1 1 3 1 3]
# Iters 1233, Path: [1 3 3 3 3]
# Iters 1234, Path: [1 3 3 3 3]
# Iters 1235, Path: [1 3 3 3 3]
# Iters 1236, Path: [1 1 3 1 3]
# Iters 1237, Path: [1 3 3 3 3]
# Iters 1238, Path: [1 3 3 3 3]
# Iters 1239, Path: [1 3 3 3 3]
# Iters 1240, Path: [1 1 3 1 3]
# Iters 1241, Path: [1 3 3 3 3]
# Iters 1242, Path: [1 3 3 3 3]
# Iters 1243, Path: [1 3 3 3 3]
# Iters 1244, Path: [1 1 3 1 3]
# Iters 1245, Path: [1 3 3 3 3]
# Iters 1246, Path: [1 3 3 3 3]
# Iters 1247, Path: [1 3 3 3 3]
# Iters 1248, Path: [1 1 3 1 3]
# Iters 1249, Path: [1 3 3 3 3]
# Iters 1250, Path: [1 3 3 3 3]
# Iters 1251, Path: [1 3 3 3 3]
# Iters 1252, Path: [1 1 3 1 3]
# Iters 1253, Path: [1 3 3 3 3]
# Iters 1254, Path: [1 3 3 3 3]
# Iters 1255, Path: [1 3 3 3 3]
# Iters 1256, Path: [1 1 3 1 3]
# Iters 1257, Path: [1 3 3 3 3]
# Iters 1258, Path: [1 3 3 3 3]
# Iters 1259, Path: [1 3 3 3 3]
# Iters 1260, Path: [1 1 3 1 3]
# Iters 1261, Path: [1 3 3 3 3]
# Iters 1262, Path: [1 3 3 3 3]
# Iters 1263, Path: [1 3 3 3 3]
# Iters 1264, Path: [1 1 3 1 3]
# Iters 1265, Path: [1 3 3 3 3]
# Iters 1266, Path: [1 3 3 3 3]
# Iters 1267, Path: [1 3 3 3 3]
# Iters 1268, Path: [1 1 3 1 3]
# Iters 1269, Path: [1 3 3 3 3]
# Iters 1270, Path: [1 3 3 3 3]
# Iters 1271, Path: [1 3 3 3 3]
# Iters 1272, Path: [1 1 3 1 3]
# Iters 1273, Path: [1 3 3 3 3]
# Iters 1274, Path: [1 3 3 3 3]
# Iters 1275, Path: [1 3 3 3 3]
# Iters 1276, Path: [1 1 3 1 3]
# Iters 1277, Path: [1 3 3 3 3]
# Iters 1278, Path: [1 3 3 3 3]
# Iters 1279, Path: [1 3 3 3 3]
# Iters 1280, Path: [1 1 3 1 3]
# Iters 1281, Path: [1 3 3 3 3]
# Iters 1282, Path: [1 3 3 3 3]
# Iters 1283, Path: [1 3 3 3 3]
# Iters 1284, Path: [1 1 3 1 3]
# Iters 1285, Path: [1 3 3 3 3]
# Iters 1286, Path: [1 3 3 3 3]
# Iters 1287, Path: [1 3 3 3 3]
# Iters 1288, Path: [1 1 3 1 3]
# Iters 1289, Path: [1 3 3 3 3]
# Iters 1290, Path: [1 3 3 3 3]
# Iters 1291, Path: [1 3 3 3 3]
# Iters 1292, Path: [1 1 3 1 3]
# Iters 1293, Path: [1 3 3 3 3]
# Iters 1294, Path: [1 3 3 3 3]
# Iters 1295, Path: [1 3 3 3 3]
# Iters 1296, Path: [1 1 3 1 3]
# Iters 1297, Path: [1 3 3 3 3]
# Iters 1298, Path: [1 3 3 3 3]
# Iters 1299, Path: [1 3 3 3 3]
# Iters 1300, Path: [1 1 3 1 3]
# Iters 1301, Path: [1 3 3 3 3]
# Iters 1302, Path: [1 3 3 3 3]
# Iters 1303, Path: [1 3 3 3 3]
# Iters 1304, Path: [1 1 3 1 3]
# Iters 1305, Path: [1 3 3 3 3]
# Iters 1306, Path: [1 3 3 3 3]
# Iters 1307, Path: [1 3 3 3 3]
# Iters 1308, Path: [1 1 3 1 3]
# Iters 1309, Path: [1 3 3 3 3]
# Iters 1310, Path: [1 3 3 3 3]
# Iters 1311, Path: [1 3 3 3 3]
# Iters 1312, Path: [1 1 3 1 3]
# Iters 1313, Path: [1 3 3 3 3]
# Iters 1314, Path: [1 3 3 3 3]
# Iters 1315, Path: [1 3 3 3 3]
# Iters 1316, Path: [1 1 3 1 3]
# Iters 1317, Path: [1 3 3 3 3]
# Iters 1318, Path: [1 3 3 3 3]
# Iters 1319, Path: [1 3 3 3 3]
# Iters 1320, Path: [1 1 3 1 3]
# Iters 1321, Path: [1 3 3 3 3]
# Iters 1322, Path: [1 3 3 3 3]
# Iters 1323, Path: [1 3 3 3 3]
# Iters 1324, Path: [1 1 3 1 3]
# Iters 1325, Path: [1 3 3 3 3]
# Iters 1326, Path: [1 3 3 3 3]
# Iters 1327, Path: [1 3 3 3 3]
# Iters 1328, Path: [1 1 3 1 3]
# Iters 1329, Path: [1 3 3 3 3]
# Iters 1330, Path: [1 3 3 3 3]
# Iters 1331, Path: [1 3 3 3 3]
# Iters 1332, Path: [1 1 3 1 3]
# Iters 1333, Path: [1 3 3 3 3]
# Iters 1334, Path: [1 3 3 3 3]
# Iters 1335, Path: [1 3 3 3 3]
# Iters 1336, Path: [1 1 3 1 3]
# Iters 1337, Path: [1 3 3 3 3]
# Iters 1338, Path: [1 3 3 3 3]
# Iters 1339, Path: [1 3 3 3 3]
# Iters 1340, Path: [1 1 3 1 3]
# Iters 1341, Path: [1 3 3 3 3]
# Iters 1342, Path: [1 3 3 3 3]
# Iters 1343, Path: [1 3 3 3 3]
# Iters 1344, Path: [1 1 3 1 3]
# Iters 1345, Path: [1 3 3 3 3]
# Iters 1346, Path: [1 3 3 3 3]
# Iters 1347, Path: [1 3 3 3 3]
# Iters 1348, Path: [1 1 3 1 3]
# Iters 1349, Path: [1 3 3 3 3]
# Iters 1350, Path: [1 3 3 3 3]
# Iters 1351, Path: [1 3 3 3 3]
# Iters 1352, Path: [1 1 3 1 3]
# Iters 1353, Path: [1 3 3 3 3]
# Iters 1354, Path: [1 3 3 3 3]
# Iters 1355, Path: [1 3 3 3 3]
# Iters 1356, Path: [1 1 3 1 3]
# Iters 1357, Path: [1 3 3 3 3]
# Iters 1358, Path: [1 3 3 3 3]
# Iters 1359, Path: [1 3 3 3 3]
# Iters 1360, Path: [1 1 3 1 3]
# Iters 1361, Path: [1 3 3 3 3]
# Iters 1362, Path: [1 3 3 3 3]
# Iters 1363, Path: [1 3 3 3 3]
# Iters 1364, Path: [1 1 3 1 3]
# Iters 1365, Path: [1 3 3 3 3]
# Iters 1366, Path: [1 3 3 3 3]
# Iters 1367, Path: [1 3 3 3 3]
# Iters 1368, Path: [1 1 3 1 3]
# Iters 1369, Path: [1 3 3 3 3]
# Iters 1370, Path: [1 3 3 3 3]
# Iters 1371, Path: [1 3 3 3 3]
# Iters 1372, Path: [1 1 3 1 3]
# Iters 1373, Path: [1 3 3 3 3]
# Iters 1374, Path: [1 3 3 3 3]
# Iters 1375, Path: [1 3 3 3 3]
# Iters 1376, Path: [1 1 3 1 3]
# Iters 1377, Path: [1 3 3 3 3]
# Iters 1378, Path: [1 3 3 3 3]
# Iters 1379, Path: [1 3 3 3 3]
# Iters 1380, Path: [1 1 3 1 3]
# Iters 1381, Path: [1 3 3 3 3]
# Iters 1382, Path: [1 3 3 3 3]
# Iters 1383, Path: [1 3 3 3 3]
# Iters 1384, Path: [1 1 3 1 3]
# Iters 1385, Path: [1 3 3 3 3]
# Iters 1386, Path: [1 3 3 3 3]
# Iters 1387, Path: [1 3 3 3 3]
# Iters 1388, Path: [1 1 3 1 3]
# Iters 1389, Path: [1 3 3 3 3]
# Iters 1390, Path: [1 3 3 3 3]
# Iters 1391, Path: [1 3 3 3 3]
# Iters 1392, Path: [1 1 3 1 3]
# Iters 1393, Path: [1 3 3 3 3]
# Iters 1394, Path: [1 3 3 3 3]
# Iters 1395, Path: [1 3 3 3 3]
# Iters 1396, Path: [1 1 3 1 3]
# Iters 1397, Path: [1 3 3 3 3]
# Iters 1398, Path: [1 3 3 3 3]
# Iters 1399, Path: [1 3 3 3 3]
# Iters 1400, Path: [1 1 3 1 3]
# Iters 1401, Path: [1 3 3 3 3]
# Iters 1402, Path: [1 3 3 3 3]
# Iters 1403, Path: [1 3 3 3 3]
# Iters 1404, Path: [1 1 3 1 3]
# Iters 1405, Path: [1 3 3 3 3]
# Iters 1406, Path: [1 3 3 3 3]
# Iters 1407, Path: [1 3 3 3 3]
# Iters 1408, Path: [1 1 3 1 3]
# Iters 1409, Path: [1 3 3 3 3]
# Iters 1410, Path: [1 3 3 3 3]
# Iters 1411, Path: [1 3 3 3 3]
# Iters 1412, Path: [1 1 3 1 3]
# Iters 1413, Path: [1 3 3 3 3]
# Iters 1414, Path: [1 3 3 3 3]
# Iters 1415, Path: [1 3 3 3 3]
# Iters 1416, Path: [1 1 3 1 3]
# Iters 1417, Path: [1 3 3 3 3]
# Iters 1418, Path: [1 3 3 3 3]
# Iters 1419, Path: [1 3 3 3 3]
# Iters 1420, Path: [1 1 3 1 3]
# Iters 1421, Path: [1 3 3 3 3]
# Iters 1422, Path: [1 3 3 3 3]
# Iters 1423, Path: [1 3 3 3 3]
# Iters 1424, Path: [1 1 3 1 3]
# Iters 1425, Path: [1 3 3 3 3]
# Iters 1426, Path: [1 3 3 3 3]
# Iters 1427, Path: [1 3 3 3 3]
# Iters 1428, Path: [1 1 3 1 3]
# Iters 1429, Path: [1 3 3 3 3]
# Iters 1430, Path: [1 3 3 3 3]
# Iters 1431, Path: [1 3 3 3 3]
# Iters 1432, Path: [1 1 3 1 3]
# Iters 1433, Path: [1 3 3 3 3]
# Iters 1434, Path: [1 3 3 3 3]
# Iters 1435, Path: [1 3 3 3 3]
# Iters 1436, Path: [1 1 3 1 3]
# Iters 1437, Path: [1 3 3 3 3]
# Iters 1438, Path: [1 3 3 3 3]
# Iters 1439, Path: [1 3 3 3 3]
# Iters 1440, Path: [1 1 3 1 3]
# Iters 1441, Path: [1 3 3 3 3]
# Iters 1442, Path: [1 3 3 3 3]
# Iters 1443, Path: [1 3 3 3 3]
# Iters 1444, Path: [1 1 3 1 3]
# Iters 1445, Path: [1 3 3 3 3]
# Iters 1446, Path: [1 3 3 3 3]
# Iters 1447, Path: [1 3 3 3 3]
# Iters 1448, Path: [1 1 3 1 3]
# Iters 1449, Path: [1 3 3 3 3]
# Iters 1450, Path: [1 3 3 3 3]
# Iters 1451, Path: [1 3 3 3 3]
# Iters 1452, Path: [1 1 3 1 3]
# Iters 1453, Path: [1 3 3 3 3]
# Iters 1454, Path: [1 3 3 3 3]
# Iters 1455, Path: [1 3 3 3 3]
# Iters 1456, Path: [1 1 3 1 3]
# Iters 1457, Path: [1 3 3 3 3]
# Iters 1458, Path: [1 3 3 3 3]
# Iters 1459, Path: [1 3 3 3 3]
# Iters 1460, Path: [1 1 3 1 3]
# Iters 1461, Path: [1 3 3 3 3]
# Iters 1462, Path: [1 3 3 3 3]
# Iters 1463, Path: [1 3 3 3 3]
# Iters 1464, Path: [1 1 3 1 3]
# Iters 1465, Path: [1 3 3 3 3]
# Iters 1466, Path: [1 3 3 3 3]
# Iters 1467, Path: [1 3 3 3 3]
# Iters 1468, Path: [1 1 3 1 3]
# Iters 1469, Path: [1 3 3 3 3]
# Iters 1470, Path: [1 3 3 3 3]
# Iters 1471, Path: [1 3 3 3 3]
# Iters 1472, Path: [1 1 3 1 3]
# Iters 1473, Path: [1 3 3 3 3]
# Iters 1474, Path: [1 3 3 3 3]
# Iters 1475, Path: [1 3 3 3 3]
# Iters 1476, Path: [1 1 3 1 3]
# Iters 1477, Path: [1 3 3 3 3]
# Iters 1478, Path: [1 3 3 3 3]
# Iters 1479, Path: [1 3 3 3 3]
# Iters 1480, Path: [1 1 3 1 3]
# Iters 1481, Path: [1 3 3 3 3]
# Iters 1482, Path: [1 3 3 3 3]
# Iters 1483, Path: [1 3 3 3 3]
# Iters 1484, Path: [1 1 3 1 3]
# Iters 1485, Path: [1 3 3 3 3]
# Iters 1486, Path: [1 3 3 3 3]
# Iters 1487, Path: [1 3 3 3 3]
# Iters 1488, Path: [1 1 3 1 3]
# Iters 1489, Path: [1 3 3 3 3]
# Iters 1490, Path: [1 3 3 3 3]
# Iters 1491, Path: [1 3 3 3 3]
# Iters 1492, Path: [1 1 3 1 3]
# Iters 1493, Path: [1 3 3 3 3]
# Iters 1494, Path: [1 3 3 3 3]
# Iters 1495, Path: [1 3 3 3 3]
# Iters 1496, Path: [1 1 3 1 3]
# Iters 1497, Path: [1 3 3 3 3]
# Iters 1498, Path: [1 3 3 3 3]
# Iters 1499, Path: [1 3 3 3 3]
# Iters 1500, Path: [1 1 3 1 3]
# Iters 1501, Path: [1 3 3 3 3]
# Iters 1502, Path: [1 3 3 3 3]
# Iters 1503, Path: [1 3 3 3 3]
# Iters 1504, Path: [1 1 3 1 3]
# Iters 1505, Path: [1 3 3 3 3]
# Iters 1506, Path: [1 3 3 3 3]
# Iters 1507, Path: [1 3 3 3 3]
# Iters 1508, Path: [1 1 3 1 3]
# Iters 1509, Path: [1 3 3 3 3]
# Iters 1510, Path: [1 3 3 3 3]
# Iters 1511, Path: [1 3 3 3 3]
# Iters 1512, Path: [1 1 3 1 3]
# Iters 1513, Path: [1 3 3 3 3]
# Iters 1514, Path: [1 3 3 3 3]
# Iters 1515, Path: [1 3 3 3 3]
# Iters 1516, Path: [1 1 3 1 3]
# Iters 1517, Path: [1 3 3 3 3]
# Iters 1518, Path: [1 3 3 3 3]
# Iters 1519, Path: [1 3 3 3 3]
# Iters 1520, Path: [1 1 3 1 3]
# Iters 1521, Path: [1 3 3 3 3]
# Iters 1522, Path: [1 3 3 3 3]
# Iters 1523, Path: [1 3 3 3 3]
# Iters 1524, Path: [1 1 3 1 3]
# Iters 1525, Path: [1 3 3 3 3]
# Iters 1526, Path: [1 3 3 3 3]
# Iters 1527, Path: [1 3 3 3 3]
# Iters 1528, Path: [1 1 3 1 3]
# Iters 1529, Path: [1 3 3 3 3]
# Iters 1530, Path: [1 3 3 3 3]
# Iters 1531, Path: [1 3 3 3 3]
# Iters 1532, Path: [1 1 3 1 3]
# Iters 1533, Path: [1 3 3 3 3]
# Iters 1534, Path: [1 3 3 3 3]
# Iters 1535, Path: [1 3 3 3 3]
# Iters 1536, Path: [1 1 3 1 3]
# Iters 1537, Path: [1 3 3 3 3]
# Iters 1538, Path: [1 3 3 3 3]
# Iters 1539, Path: [1 3 3 3 3]
# Iters 1540, Path: [1 1 3 1 3]
# Iters 1541, Path: [1 3 3 3 3]
# Iters 1542, Path: [1 3 3 3 3]
# Iters 1543, Path: [1 3 3 3 3]
# Iters 1544, Path: [1 1 3 1 3]
# Iters 1545, Path: [1 3 3 3 3]
# Iters 1546, Path: [1 3 3 3 3]
# Iters 1547, Path: [1 3 3 3 3]
# Iters 1548, Path: [1 1 3 1 3]
# Iters 1549, Path: [1 3 3 3 3]
# Iters 1550, Path: [1 3 3 3 3]
# Iters 1551, Path: [1 3 3 3 3]
# Iters 1552, Path: [1 1 3 1 3]
# Iters 1553, Path: [1 3 3 3 3]
# Iters 1554, Path: [1 3 3 3 3]
# Iters 1555, Path: [1 3 3 3 3]
# Iters 1556, Path: [1 1 3 1 3]
# Iters 1557, Path: [1 3 3 3 3]
# Iters 1558, Path: [1 3 3 3 3]
# Iters 1559, Path: [1 3 3 3 3]
# Iters 1560, Path: [1 1 3 1 3]
# Iters 1561, Path: [1 3 3 3 3]
# Iters 1562, Path: [1 3 3 3 3]
# Iters 1563, Path: [1 3 3 3 3]
# Iters 1564, Path: [1 1 3 1 3]
# Iters 1565, Path: [1 3 3 3 3]
# Iters 1566, Path: [1 3 3 3 3]
# Iters 1567, Path: [1 3 3 3 3]
# Iters 1568, Path: [1 1 3 1 3]
# Iters 1569, Path: [1 3 3 3 3]
# Iters 1570, Path: [1 3 3 3 3]
# Iters 1571, Path: [1 3 3 3 3]
# Iters 1572, Path: [1 1 3 1 3]
# Iters 1573, Path: [1 3 3 3 3]
# Iters 1574, Path: [1 3 3 3 3]
# Iters 1575, Path: [1 3 3 3 3]
# Iters 1576, Path: [1 1 3 1 3]
# Iters 1577, Path: [1 3 3 3 3]
# Iters 1578, Path: [1 3 3 3 3]
# Iters 1579, Path: [1 3 3 3 3]
# Iters 1580, Path: [1 1 3 1 3]
# Iters 1581, Path: [1 3 3 3 3]
# Iters 1582, Path: [1 3 3 3 3]
# Iters 1583, Path: [1 3 3 3 3]
# Iters 1584, Path: [1 1 3 1 3]
# Iters 1585, Path: [1 3 3 3 3]
# Iters 1586, Path: [1 3 3 3 3]
# Iters 1587, Path: [1 3 3 3 3]
# Iters 1588, Path: [1 1 3 1 3]
# Iters 1589, Path: [1 3 3 3 3]
# Iters 1590, Path: [1 3 3 3 3]
# Iters 1591, Path: [1 3 3 3 3]
# Iters 1592, Path: [1 1 3 1 3]
# Iters 1593, Path: [1 3 3 3 3]
# Iters 1594, Path: [1 3 3 3 3]
# Iters 1595, Path: [1 3 3 3 3]
# Iters 1596, Path: [1 1 3 1 3]
# Iters 1597, Path: [1 3 3 3 3]
# Iters 1598, Path: [1 3 3 3 3]
# Iters 1599, Path: [1 3 3 3 3]
# Iters 1600, Path: [1 1 3 1 3]
# Iters 1601, Path: [1 3 3 3 3]
# Iters 1602, Path: [1 3 3 3 3]
# Iters 1603, Path: [1 3 3 3 3]
# Iters 1604, Path: [1 1 3 1 3]
# Iters 1605, Path: [1 3 3 3 3]
# Iters 1606, Path: [1 3 3 3 3]
# Iters 1607, Path: [1 3 3 3 3]
# Iters 1608, Path: [1 1 3 1 3]
# Iters 1609, Path: [1 3 3 3 3]
# Iters 1610, Path: [1 3 3 3 3]
# Iters 1611, Path: [1 3 3 3 3]
# Iters 1612, Path: [1 1 3 1 3]
# Iters 1613, Path: [1 3 3 3 3]
# Iters 1614, Path: [1 3 3 3 3]
# Iters 1615, Path: [1 3 3 3 3]
# Iters 1616, Path: [1 1 3 1 3]
# Iters 1617, Path: [1 3 3 3 3]
# Iters 1618, Path: [1 3 3 3 3]
# Iters 1619, Path: [1 3 3 3 3]
# Iters 1620, Path: [1 1 3 1 3]
# Iters 1621, Path: [1 3 3 3 3]
# Iters 1622, Path: [1 3 3 3 3]
# Iters 1623, Path: [1 3 3 3 3]
# Iters 1624, Path: [1 1 3 1 3]
# Iters 1625, Path: [1 3 3 3 3]
# Iters 1626, Path: [1 3 3 3 3]
# Iters 1627, Path: [1 3 3 3 3]
# Iters 1628, Path: [1 1 3 1 3]
# Iters 1629, Path: [1 3 3 3 3]
# Iters 1630, Path: [1 3 3 3 3]
# Iters 1631, Path: [1 3 3 3 3]
# Iters 1632, Path: [1 1 3 1 3]
# Iters 1633, Path: [1 3 3 3 3]
# Iters 1634, Path: [1 3 3 3 3]
# Iters 1635, Path: [1 3 3 3 3]
# Iters 1636, Path: [1 1 3 1 3]
# ...
# Iters 9468, Path: [1 1 3 1 3]
# Iters 9469, Path: [1 3 3 3 3]
# Iters 9470, Path: [1 3 3 3 3]
# Iters 9471, Path: [1 3 3 3 3]
# Iters 9472, Path: [1 1 3 1 3]
# Iters 9473, Path: [1 3 3 3 3]
# Iters 9474, Path: [1 3 3 3 3]
# Iters 9475, Path: [1 3 3 3 3]
# Iters 9476, Path: [1 1 3 1 3]
# Iters 9477, Path: [1 3 3 3 3]
# Iters 9478, Path: [1 3 3 3 3]
# Iters 9479, Path: [1 3 3 3 3]
# Iters 9480, Path: [1 1 3 1 3]
# Iters 9481, Path: [1 3 3 3 3]
# Iters 9482, Path: [1 3 3 3 3]
# Iters 9483, Path: [1 3 3 3 3]
# Iters 9484, Path: [1 1 3 1 3]
# Iters 9485, Path: [1 3 3 3 3]
# Iters 9486, Path: [1 3 3 3 3]
# Iters 9487, Path: [1 3 3 3 3]
# Iters 9488, Path: [1 1 3 1 3]
# Iters 9489, Path: [1 3 3 3 3]
# Iters 9490, Path: [1 3 3 3 3]
# Iters 9491, Path: [1 3 3 3 3]
# Iters 9492, Path: [1 1 3 1 3]
# Iters 9493, Path: [1 3 3 3 3]
# Iters 9494, Path: [1 3 3 3 3]
# Iters 9495, Path: [1 3 3 3 3]
# Iters 9496, Path: [1 1 3 1 3]
# Iters 9497, Path: [1 3 3 3 3]
# Iters 9498, Path: [1 3 3 3 3]
# Iters 9499, Path: [1 3 3 3 3]
# Iters 9500, Path: [1 1 3 1 3]
# Iters 9501, Path: [1 3 3 3 3]
# Iters 9502, Path: [1 3 3 3 3]
# Iters 9503, Path: [1 3 3 3 3]
# Iters 9504, Path: [1 1 3 1 3]
# Iters 9505, Path: [1 3 3 3 3]
# Iters 9506, Path: [1 3 3 3 3]
# Iters 9507, Path: [1 3 3 3 3]
# Iters 9508, Path: [1 1 3 1 3]
# Iters 9509, Path: [1 3 3 3 3]
# Iters 9510, Path: [1 3 3 3 3]
# Iters 9511, Path: [1 3 3 3 3]
# Iters 9512, Path: [1 1 3 1 3]
# Iters 9513, Path: [1 3 3 3 3]
# Iters 9514, Path: [1 3 3 3 3]
# Iters 9515, Path: [1 3 3 3 3]
# Iters 9516, Path: [1 1 3 1 3]
# Iters 9517, Path: [1 3 3 3 3]
# Iters 9518, Path: [1 3 3 3 3]
# Iters 9519, Path: [1 3 3 3 3]
# Iters 9520, Path: [1 1 3 1 3]
# Iters 9521, Path: [1 3 3 3 3]
# Iters 9522, Path: [1 3 3 3 3]
# Iters 9523, Path: [1 3 3 3 3]
# Iters 9524, Path: [1 1 3 1 3]
# Iters 9525, Path: [1 3 3 3 3]
# Iters 9526, Path: [1 3 3 3 3]
# Iters 9527, Path: [1 3 3 3 3]
# Iters 9528, Path: [1 1 3 1 3]
# Iters 9529, Path: [1 3 3 3 3]
# Iters 9530, Path: [1 3 3 3 3]
# Iters 9531, Path: [1 3 3 3 3]
# Iters 9532, Path: [1 1 3 1 3]
# Iters 9533, Path: [1 3 3 3 3]
# Iters 9534, Path: [1 3 3 3 3]
# Iters 9535, Path: [1 3 3 3 3]
# Iters 9536, Path: [1 1 3 1 3]
# Iters 9537, Path: [1 3 3 3 3]
# Iters 9538, Path: [1 3 3 3 3]
# Iters 9539, Path: [1 3 3 3 3]
# Iters 9540, Path: [1 1 3 1 3]
# Iters 9541, Path: [1 3 3 3 3]
# Iters 9542, Path: [1 3 3 3 3]
# Iters 9543, Path: [1 3 3 3 3]
# Iters 9544, Path: [1 1 3 1 3]
# Iters 9545, Path: [1 3 3 3 3]
# Iters 9546, Path: [1 3 3 3 3]
# Iters 9547, Path: [1 3 3 3 3]
# Iters 9548, Path: [1 1 3 1 3]
# Iters 9549, Path: [1 3 3 3 3]
# Iters 9550, Path: [1 3 3 3 3]
# Iters 9551, Path: [1 3 3 3 3]
# Iters 9552, Path: [1 1 3 1 3]
# Iters 9553, Path: [1 3 3 3 3]
# Iters 9554, Path: [1 3 3 3 3]
# Iters 9555, Path: [1 3 3 3 3]
# Iters 9556, Path: [1 1 3 1 3]
# Iters 9557, Path: [1 3 3 3 3]
# Iters 9558, Path: [1 3 3 3 3]
# Iters 9559, Path: [1 3 3 3 3]
# Iters 9560, Path: [1 1 3 1 3]
# Iters 9561, Path: [1 3 3 3 3]
# Iters 9562, Path: [1 3 3 3 3]
# Iters 9563, Path: [1 3 3 3 3]
# Iters 9564, Path: [1 1 3 1 3]
# Iters 9565, Path: [1 3 3 3 3]
# Iters 9566, Path: [1 3 3 3 3]
# Iters 9567, Path: [1 3 3 3 3]
# Iters 9568, Path: [1 1 3 1 3]
# Iters 9569, Path: [1 3 3 3 3]
# Iters 9570, Path: [1 3 3 3 3]
# Iters 9571, Path: [1 3 3 3 3]
# Iters 9572, Path: [1 1 3 1 3]
# Iters 9573, Path: [1 3 3 3 3]
# Iters 9574, Path: [1 3 3 3 3]
# Iters 9575, Path: [1 3 3 3 3]
# Iters 9576, Path: [1 1 3 1 3]
# Iters 9577, Path: [1 3 3 3 3]
# Iters 9578, Path: [1 3 3 3 3]
# Iters 9579, Path: [1 3 3 3 3]
# Iters 9580, Path: [1 1 3 1 3]
# Iters 9581, Path: [1 3 3 3 3]
# Iters 9582, Path: [1 3 3 3 3]
# Iters 9583, Path: [1 3 3 3 3]
# Iters 9584, Path: [1 1 3 1 3]
# Iters 9585, Path: [1 3 3 3 3]
# Iters 9586, Path: [1 3 3 3 3]
# Iters 9587, Path: [1 3 3 3 3]
# Iters 9588, Path: [1 1 3 1 3]
# Iters 9589, Path: [1 3 3 3 3]
# Iters 9590, Path: [1 3 3 3 3]
# Iters 9591, Path: [1 3 3 3 3]
# Iters 9592, Path: [1 1 3 1 3]
# Iters 9593, Path: [1 3 3 3 3]
# Iters 9594, Path: [1 3 3 3 3]
# Iters 9595, Path: [1 3 3 3 3]
# Iters 9596, Path: [1 1 3 1 3]
# Iters 9597, Path: [1 3 3 3 3]
# Iters 9598, Path: [1 3 3 3 3]
# Iters 9599, Path: [1 3 3 3 3]
# Iters 9600, Path: [1 1 3 1 3]
# Iters 9601, Path: [1 3 3 3 3]
# Iters 9602, Path: [1 3 3 3 3]
# Iters 9603, Path: [1 3 3 3 3]
# Iters 9604, Path: [1 1 3 1 3]
# Iters 9605, Path: [1 3 3 3 3]
# Iters 9606, Path: [1 3 3 3 3]
# Iters 9607, Path: [1 3 3 3 3]
# Iters 9608, Path: [1 1 3 1 3]
# Iters 9609, Path: [1 3 3 3 3]
# Iters 9610, Path: [1 3 3 3 3]
# Iters 9611, Path: [1 3 3 3 3]
# Iters 9612, Path: [1 1 3 1 3]
# Iters 9613, Path: [1 3 3 3 3]
# Iters 9614, Path: [1 3 3 3 3]
# Iters 9615, Path: [1 3 3 3 3]
# Iters 9616, Path: [1 1 3 1 3]
# Iters 9617, Path: [1 3 3 3 3]
# Iters 9618, Path: [1 3 3 3 3]
# Iters 9619, Path: [1 3 3 3 3]
# Iters 9620, Path: [1 1 3 1 3]
# Iters 9621, Path: [1 3 3 3 3]
# Iters 9622, Path: [1 3 3 3 3]
# Iters 9623, Path: [1 3 3 3 3]
# Iters 9624, Path: [1 1 3 1 3]
# Iters 9625, Path: [1 3 3 3 3]
# Iters 9626, Path: [1 3 3 3 3]
# Iters 9627, Path: [1 3 3 3 3]
# Iters 9628, Path: [1 1 3 1 3]
# Iters 9629, Path: [1 3 3 3 3]
# Iters 9630, Path: [1 3 3 3 3]
# Iters 9631, Path: [1 3 3 3 3]
# Iters 9632, Path: [1 1 3 1 3]
# Iters 9633, Path: [1 3 3 3 3]
# Iters 9634, Path: [1 3 3 3 3]
# Iters 9635, Path: [1 3 3 3 3]
# Iters 9636, Path: [1 1 3 1 3]
# Iters 9637, Path: [1 3 3 3 3]
# Iters 9638, Path: [1 3 3 3 3]
# Iters 9639, Path: [1 3 3 3 3]
# Iters 9640, Path: [1 1 3 1 3]
# Iters 9641, Path: [1 3 3 3 3]
# Iters 9642, Path: [1 3 3 3 3]
# Iters 9643, Path: [1 3 3 3 3]
# Iters 9644, Path: [1 1 3 1 3]
# Iters 9645, Path: [1 3 3 3 3]
# Iters 9646, Path: [1 3 3 3 3]
# Iters 9647, Path: [1 3 3 3 3]
# Iters 9648, Path: [1 1 3 1 3]
# Iters 9649, Path: [1 3 3 3 3]
# Iters 9650, Path: [1 3 3 3 3]
# Iters 9651, Path: [1 3 3 3 3]
# Iters 9652, Path: [1 1 3 1 3]
# Iters 9653, Path: [1 3 3 3 3]
# Iters 9654, Path: [1 3 3 3 3]
# Iters 9655, Path: [1 3 3 3 3]
# Iters 9656, Path: [1 1 3 1 3]
# Iters 9657, Path: [1 3 3 3 3]
# Iters 9658, Path: [1 3 3 3 3]
# Iters 9659, Path: [1 3 3 3 3]
# Iters 9660, Path: [1 1 3 1 3]
# Iters 9661, Path: [1 3 3 3 3]
# Iters 9662, Path: [1 3 3 3 3]
# Iters 9663, Path: [1 3 3 3 3]
# Iters 9664, Path: [1 1 3 1 3]
# Iters 9665, Path: [1 3 3 3 3]
# Iters 9666, Path: [1 3 3 3 3]
# Iters 9667, Path: [1 3 3 3 3]
# Iters 9668, Path: [1 1 3 1 3]
# Iters 9669, Path: [1 3 3 3 3]
# Iters 9670, Path: [1 3 3 3 3]
# Iters 9671, Path: [1 3 3 3 3]
# Iters 9672, Path: [1 1 3 1 3]
# Iters 9673, Path: [1 3 3 3 3]
# Iters 9674, Path: [1 3 3 3 3]
# Iters 9675, Path: [1 3 3 3 3]
# Iters 9676, Path: [1 1 3 1 3]
# Iters 9677, Path: [1 3 3 3 3]
# Iters 9678, Path: [1 3 3 3 3]
# Iters 9679, Path: [1 3 3 3 3]
# Iters 9680, Path: [1 1 3 1 3]
# Iters 9681, Path: [1 3 3 3 3]
# Iters 9682, Path: [1 3 3 3 3]
# Iters 9683, Path: [1 3 3 3 3]
# Iters 9684, Path: [1 1 3 1 3]
# Iters 9685, Path: [1 3 3 3 3]
# Iters 9686, Path: [1 3 3 3 3]
# Iters 9687, Path: [1 3 3 3 3]
# Iters 9688, Path: [1 1 3 1 3]
# Iters 9689, Path: [1 3 3 3 3]
# Iters 9690, Path: [1 3 3 3 3]
# Iters 9691, Path: [1 3 3 3 3]
# Iters 9692, Path: [1 1 3 1 3]
# Iters 9693, Path: [1 3 3 3 3]
# Iters 9694, Path: [1 3 3 3 3]
# Iters 9695, Path: [1 3 3 3 3]
# Iters 9696, Path: [1 1 3 1 3]
# Iters 9697, Path: [1 3 3 3 3]
# Iters 9698, Path: [1 3 3 3 3]
# Iters 9699, Path: [1 3 3 3 3]
# Iters 9700, Path: [1 1 3 1 3]
# Iters 9701, Path: [1 3 3 3 3]
# Iters 9702, Path: [1 3 3 3 3]
# Iters 9703, Path: [1 3 3 3 3]
# Iters 9704, Path: [1 1 3 1 3]
# Iters 9705, Path: [1 3 3 3 3]
# Iters 9706, Path: [1 3 3 3 3]
# Iters 9707, Path: [1 3 3 3 3]
# Iters 9708, Path: [1 1 3 1 3]
# Iters 9709, Path: [1 3 3 3 3]
# Iters 9710, Path: [1 3 3 3 3]
# Iters 9711, Path: [1 3 3 3 3]
# Iters 9712, Path: [1 1 3 1 3]
# Iters 9713, Path: [1 3 3 3 3]
# Iters 9714, Path: [1 3 3 3 3]
# Iters 9715, Path: [1 3 3 3 3]
# Iters 9716, Path: [1 1 3 1 3]
# Iters 9717, Path: [1 3 3 3 3]
# Iters 9718, Path: [1 3 3 3 3]
# Iters 9719, Path: [1 3 3 3 3]
# Iters 9720, Path: [1 1 3 1 3]
# Iters 9721, Path: [1 3 3 3 3]
# Iters 9722, Path: [1 3 3 3 3]
# Iters 9723, Path: [1 3 3 3 3]
# Iters 9724, Path: [1 1 3 1 3]
# Iters 9725, Path: [1 3 3 3 3]
# Iters 9726, Path: [1 3 3 3 3]
# Iters 9727, Path: [1 3 3 3 3]
# Iters 9728, Path: [1 1 3 1 3]
# Iters 9729, Path: [1 3 3 3 3]
# Iters 9730, Path: [1 3 3 3 3]
# Iters 9731, Path: [1 3 3 3 3]
# Iters 9732, Path: [1 1 3 1 3]
# Iters 9733, Path: [1 3 3 3 3]
# Iters 9734, Path: [1 3 3 3 3]
# Iters 9735, Path: [1 3 3 3 3]
# Iters 9736, Path: [1 1 3 1 3]
# Iters 9737, Path: [1 3 3 3 3]
# Iters 9738, Path: [1 3 3 3 3]
# Iters 9739, Path: [1 3 3 3 3]
# Iters 9740, Path: [1 1 3 1 3]
# Iters 9741, Path: [1 3 3 3 3]
# Iters 9742, Path: [1 3 3 3 3]
# Iters 9743, Path: [1 3 3 3 3]
# Iters 9744, Path: [1 1 3 1 3]
# Iters 9745, Path: [1 3 3 3 3]
# Iters 9746, Path: [1 3 3 3 3]
# Iters 9747, Path: [1 3 3 3 3]
# Iters 9748, Path: [1 1 3 1 3]
# Iters 9749, Path: [1 3 3 3 3]
# Iters 9750, Path: [1 3 3 3 3]
# Iters 9751, Path: [1 3 3 3 3]
# Iters 9752, Path: [1 1 3 1 3]
# Iters 9753, Path: [1 3 3 3 3]
# Iters 9754, Path: [1 3 3 3 3]
# Iters 9755, Path: [1 3 3 3 3]
# Iters 9756, Path: [1 1 3 1 3]
# Iters 9757, Path: [1 3 3 3 3]
# Iters 9758, Path: [1 3 3 3 3]
# Iters 9759, Path: [1 3 3 3 3]
# Iters 9760, Path: [1 1 3 1 3]
# Iters 9761, Path: [1 3 3 3 3]
# Iters 9762, Path: [1 3 3 3 3]
# Iters 9763, Path: [1 3 3 3 3]
# Iters 9764, Path: [1 1 3 1 3]
# Iters 9765, Path: [1 3 3 3 3]
# Iters 9766, Path: [1 3 3 3 3]
# Iters 9767, Path: [1 3 3 3 3]
# Iters 9768, Path: [1 1 3 1 3]
# Iters 9769, Path: [1 3 3 3 3]
# Iters 9770, Path: [1 3 3 3 3]
# Iters 9771, Path: [1 3 3 3 3]
# Iters 9772, Path: [1 1 3 1 3]
# Iters 9773, Path: [1 3 3 3 3]
# Iters 9774, Path: [1 3 3 3 3]
# Iters 9775, Path: [1 3 3 3 3]
# Iters 9776, Path: [1 1 3 1 3]
# Iters 9777, Path: [1 3 3 3 3]
# Iters 9778, Path: [1 3 3 3 3]
# Iters 9779, Path: [1 3 3 3 3]
# Iters 9780, Path: [1 1 3 1 3]
# Iters 9781, Path: [1 3 3 3 3]
# Iters 9782, Path: [1 3 3 3 3]
# Iters 9783, Path: [1 3 3 3 3]
# Iters 9784, Path: [1 1 3 1 3]
# Iters 9785, Path: [1 3 3 3 3]
# Iters 9786, Path: [1 3 3 3 3]
# Iters 9787, Path: [1 3 3 3 3]
# Iters 9788, Path: [1 1 3 1 3]
# Iters 9789, Path: [1 3 3 3 3]
# Iters 9790, Path: [1 3 3 3 3]
# Iters 9791, Path: [1 3 3 3 3]
# Iters 9792, Path: [1 1 3 1 3]
# Iters 9793, Path: [1 3 3 3 3]
# Iters 9794, Path: [1 3 3 3 3]
# Iters 9795, Path: [1 3 3 3 3]
# Iters 9796, Path: [1 1 3 1 3]
# Iters 9797, Path: [1 3 3 3 3]
# Iters 9798, Path: [1 3 3 3 3]
# Iters 9799, Path: [1 3 3 3 3]
# Iters 9800, Path: [1 1 3 1 3]
# Iters 9801, Path: [1 3 3 3 3]
# Iters 9802, Path: [1 3 3 3 3]
# Iters 9803, Path: [1 3 3 3 3]
# Iters 9804, Path: [1 1 3 1 3]
# Iters 9805, Path: [1 3 3 3 3]
# Iters 9806, Path: [1 3 3 3 3]
# Iters 9807, Path: [1 3 3 3 3]
# Iters 9808, Path: [1 1 3 1 3]
# Iters 9809, Path: [1 3 3 3 3]
# Iters 9810, Path: [1 3 3 3 3]
# Iters 9811, Path: [1 3 3 3 3]
# Iters 9812, Path: [1 1 3 1 3]
# Iters 9813, Path: [1 3 3 3 3]
# Iters 9814, Path: [1 3 3 3 3]
# Iters 9815, Path: [1 3 3 3 3]
# Iters 9816, Path: [1 1 3 1 3]
# Iters 9817, Path: [1 3 3 3 3]
# Iters 9818, Path: [1 3 3 3 3]
# Iters 9819, Path: [1 3 3 3 3]
# Iters 9820, Path: [1 1 3 1 3]
# Iters 9821, Path: [1 3 3 3 3]
# Iters 9822, Path: [1 3 3 3 3]
# Iters 9823, Path: [1 3 3 3 3]
# Iters 9824, Path: [1 1 3 1 3]
# Iters 9825, Path: [1 3 3 3 3]
# Iters 9826, Path: [1 3 3 3 3]
# Iters 9827, Path: [1 3 3 3 3]
# Iters 9828, Path: [1 1 3 1 3]
# Iters 9829, Path: [1 3 3 3 3]
# Iters 9830, Path: [1 3 3 3 3]
# Iters 9831, Path: [1 3 3 3 3]
# Iters 9832, Path: [1 1 3 1 3]
# Iters 9833, Path: [1 3 3 3 3]
# Iters 9834, Path: [1 3 3 3 3]
# Iters 9835, Path: [1 3 3 3 3]
# Iters 9836, Path: [1 1 3 1 3]
# Iters 9837, Path: [1 3 3 3 3]
# Iters 9838, Path: [1 3 3 3 3]
# Iters 9839, Path: [1 3 3 3 3]
# Iters 9840, Path: [1 1 3 1 3]
# Iters 9841, Path: [1 3 3 3 3]
# Iters 9842, Path: [1 3 3 3 3]
# Iters 9843, Path: [1 3 3 3 3]
# Iters 9844, Path: [1 1 3 1 3]
# Iters 9845, Path: [1 3 3 3 3]
# Iters 9846, Path: [1 3 3 3 3]
# Iters 9847, Path: [1 3 3 3 3]
# Iters 9848, Path: [1 1 3 1 3]
# Iters 9849, Path: [1 3 3 3 3]
# Iters 9850, Path: [1 3 3 3 3]
# Iters 9851, Path: [1 3 3 3 3]
# Iters 9852, Path: [1 1 3 1 3]
# Iters 9853, Path: [1 3 3 3 3]
# Iters 9854, Path: [1 3 3 3 3]
# Iters 9855, Path: [1 3 3 3 3]
# Iters 9856, Path: [1 1 3 1 3]
# Iters 9857, Path: [1 3 3 3 3]
# Iters 9858, Path: [1 3 3 3 3]
# Iters 9859, Path: [1 3 3 3 3]
# Iters 9860, Path: [1 1 3 1 3]
# Iters 9861, Path: [1 3 3 3 3]
# Iters 9862, Path: [1 3 3 3 3]
# Iters 9863, Path: [1 3 3 3 3]
# Iters 9864, Path: [1 1 3 1 3]
# Iters 9865, Path: [1 3 3 3 3]
# Iters 9866, Path: [1 3 3 3 3]
# Iters 9867, Path: [1 3 3 3 3]
# Iters 9868, Path: [1 1 3 1 3]
# Iters 9869, Path: [1 3 3 3 3]
# Iters 9870, Path: [1 3 3 3 3]
# Iters 9871, Path: [1 3 3 3 3]
# Iters 9872, Path: [1 1 3 1 3]
# Iters 9873, Path: [1 3 3 3 3]
# Iters 9874, Path: [1 3 3 3 3]
# Iters 9875, Path: [1 3 3 3 3]
# Iters 9876, Path: [1 1 3 1 3]
# Iters 9877, Path: [1 3 3 3 3]
# Iters 9878, Path: [1 3 3 3 3]
# Iters 9879, Path: [1 3 3 3 3]
# Iters 9880, Path: [1 1 3 1 3]
# Iters 9881, Path: [1 3 3 3 3]
# Iters 9882, Path: [1 3 3 3 3]
# Iters 9883, Path: [1 3 3 3 3]
# Iters 9884, Path: [1 1 3 1 3]
# Iters 9885, Path: [1 3 3 3 3]
# Iters 9886, Path: [1 3 3 3 3]
# Iters 9887, Path: [1 3 3 3 3]
# Iters 9888, Path: [1 1 3 1 3]
# Iters 9889, Path: [1 3 3 3 3]
# Iters 9890, Path: [1 3 3 3 3]
# Iters 9891, Path: [1 3 3 3 3]
# Iters 9892, Path: [1 1 3 1 3]
# Iters 9893, Path: [1 3 3 3 3]
# Iters 9894, Path: [1 3 3 3 3]
# Iters 9895, Path: [1 3 3 3 3]
# Iters 9896, Path: [1 1 3 1 3]
# Iters 9897, Path: [1 3 3 3 3]
# Iters 9898, Path: [1 3 3 3 3]
# Iters 9899, Path: [1 3 3 3 3]
# Iters 9900, Path: [1 1 3 1 3]
# Iters 9901, Path: [1 3 3 3 3]
# Iters 9902, Path: [1 3 3 3 3]
# Iters 9903, Path: [1 3 3 3 3]
# Iters 9904, Path: [1 1 3 1 3]
# Iters 9905, Path: [1 3 3 3 3]
# Iters 9906, Path: [1 3 3 3 3]
# Iters 9907, Path: [1 3 3 3 3]
# Iters 9908, Path: [1 1 3 1 3]
# Iters 9909, Path: [1 3 3 3 3]
# Iters 9910, Path: [1 3 3 3 3]
# Iters 9911, Path: [1 3 3 3 3]
# Iters 9912, Path: [1 1 3 1 3]
# Iters 9913, Path: [1 3 3 3 3]
# Iters 9914, Path: [1 3 3 3 3]
# Iters 9915, Path: [1 3 3 3 3]
# Iters 9916, Path: [1 1 3 1 3]
# Iters 9917, Path: [1 3 3 3 3]
# Iters 9918, Path: [1 3 3 3 3]
# Iters 9919, Path: [1 3 3 3 3]
# Iters 9920, Path: [1 1 3 1 3]
# Iters 9921, Path: [1 3 3 3 3]
# Iters 9922, Path: [1 3 3 3 3]
# Iters 9923, Path: [1 3 3 3 3]
# Iters 9924, Path: [1 1 3 1 3]
# Iters 9925, Path: [1 3 3 3 3]
# Iters 9926, Path: [1 3 3 3 3]
# Iters 9927, Path: [1 3 3 3 3]
# Iters 9928, Path: [1 1 3 1 3]
# Iters 9929, Path: [1 3 3 3 3]
# Iters 9930, Path: [1 3 3 3 3]
# Iters 9931, Path: [1 3 3 3 3]
# Iters 9932, Path: [1 1 3 1 3]
# Iters 9933, Path: [1 3 3 3 3]
# Iters 9934, Path: [1 3 3 3 3]
# Iters 9935, Path: [1 3 3 3 3]
# Iters 9936, Path: [1 1 3 1 3]
# Iters 9937, Path: [1 3 3 3 3]
# Iters 9938, Path: [1 3 3 3 3]
# Iters 9939, Path: [1 3 3 3 3]
# Iters 9940, Path: [1 1 3 1 3]
# Iters 9941, Path: [1 3 3 3 3]
# Iters 9942, Path: [1 3 3 3 3]
# Iters 9943, Path: [1 3 3 3 3]
# Iters 9944, Path: [1 1 3 1 3]
# Iters 9945, Path: [1 3 3 3 3]
# Iters 9946, Path: [1 3 3 3 3]
# Iters 9947, Path: [1 3 3 3 3]
# Iters 9948, Path: [1 1 3 1 3]
# Iters 9949, Path: [1 3 3 3 3]
# Iters 9950, Path: [1 3 3 3 3]
# Iters 9951, Path: [1 3 3 3 3]
# Iters 9952, Path: [1 1 3 1 3]
# Iters 9953, Path: [1 3 3 3 3]
# Iters 9954, Path: [1 3 3 3 3]
# Iters 9955, Path: [1 3 3 3 3]
# Iters 9956, Path: [1 1 3 1 3]
# Iters 9957, Path: [1 3 3 3 3]
# Iters 9958, Path: [1 3 3 3 3]
# Iters 9959, Path: [1 3 3 3 3]
# Iters 9960, Path: [1 1 3 1 3]
# Iters 9961, Path: [1 3 3 3 3]
# Iters 9962, Path: [1 3 3 3 3]
# Iters 9963, Path: [1 3 3 3 3]
# Iters 9964, Path: [1 1 3 1 3]
# Iters 9965, Path: [1 3 3 3 3]
# Iters 9966, Path: [1 3 3 3 3]
# Iters 9967, Path: [1 3 3 3 3]
# Iters 9968, Path: [1 1 3 1 3]
# Iters 9969, Path: [1 3 3 3 3]
# Iters 9970, Path: [1 3 3 3 3]
# Iters 9971, Path: [1 3 3 3 3]
# Iters 9972, Path: [1 1 3 1 3]
# Iters 9973, Path: [1 3 3 3 3]
# Iters 9974, Path: [1 3 3 3 3]
# Iters 9975, Path: [1 3 3 3 3]
# Iters 9976, Path: [1 1 3 1 3]
# Iters 9977, Path: [1 3 3 3 3]
# Iters 9978, Path: [1 3 3 3 3]
# Iters 9979, Path: [1 3 3 3 3]
# Iters 9980, Path: [1 1 3 1 3]
# Iters 9981, Path: [1 3 3 3 3]
# Iters 9982, Path: [1 3 3 3 3]
# Iters 9983, Path: [1 3 3 3 3]
# Iters 9984, Path: [1 1 3 1 3]
# Iters 9985, Path: [1 3 3 3 3]
# Iters 9986, Path: [1 3 3 3 3]
# Iters 9987, Path: [1 3 3 3 3]
# Iters 9988, Path: [1 1 3 1 3]
# Iters 9989, Path: [1 3 3 3 3]
# Iters 9990, Path: [1 3 3 3 3]
# Iters 9991, Path: [1 3 3 3 3]
# Iters 9992, Path: [1 1 3 1 3]
# Iters 9993, Path: [1 3 3 3 3]
# Iters 9994, Path: [1 3 3 3 3]
# Iters 9995, Path: [1 3 3 3 3]
# Iters 9996, Path: [1 1 3 1 3]
# Iters 9997, Path: [1 3 3 3 3]
# Iters 9998, Path: [1 3 3 3 3]
# Iters 9999, Path: [1 3 3 3 3]
# Iters 10000, Path: [1 1 3 1 3]

# %%
for i in range(9997, 10001):
    print('============ Iter {} ============'.format(i))
    print('A:\n{}'.format(records[i][0]))
    print('B:\n{}'.format(records[i][1]))
    print('PI:\n{}'.format(records[i][2]))
# Out:
# ============ Iter 9997 ============
# A:
# [[1.11270653e-07 0.00000000e+00 9.99999888e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.33546929e-03 0.00000000e+00 9.98657059e-01]]
# B:
# [[1.         0.        ]
#  [0.         0.        ]
#  [0.99865692 0.00133561]]
# PI:
# [1.80200478e-09 0.00000000e+00 0.00000000e+00]
# ============ Iter 9998 ============
# A:
# [[1.11420532e-07 0.00000000e+00 9.99999889e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.33440549e-03 0.00000000e+00 9.98665594e-01]]
# B:
# [[1.        0.       ]
#  [0.        0.       ]
#  [0.0021499 0.9978501]]
# PI:
# [0.1931477 0.        0.       ]
# ============ Iter 9999 ============
# A:
# [[2.46635244e-07 0.00000000e+00 9.99999753e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.68121489e-06 0.00000000e+00 9.99998319e-01]]
# B:
# [[1.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00]
#  [9.99993939e-01 6.06139305e-06]]
# PI:
# [0.99801121 0.         0.        ]
# ============ Iter 10000 ============
# A:
# [[2.46636739e-07 0.00000000e+00 9.99999753e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.68122508e-06 0.00000000e+00 9.99998319e-01]]
# B:
# [[1.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00]
#  [9.35217114e-11 1.00000000e+00]]
# PI:
# [0.99999835 0.         0.        ]
